# %% [markdown]
# # Multi-Dataset EEG-ARNN Notebook
#
# This notebook ports the EEG-ARNN workflow from the implementation notes into code.
# We load three motor-imagery datasets (BCI Competition IV 2a, BCI Competition IV 2b, and PhysioNet),
# sample manageable chunks, run exploratory analysis, train CNN and GCN variants, and compare results.

# %% [markdown]
# ## Notebook Roadmap
# - Environment setup and imports
# - Dataset configuration and helper utilities
# - Chunked loading + preprocessing per dataset (BCI 2a, BCI 2b, PhysioNet)
# - Exploratory visualisations for each dataset
# - EEG-ARNN model definition (CNN baseline + graph-enhanced model)
# - Training loop per dataset with history capture
# - Cross-dataset metric comparison plots
# - Notes on scaling up and future experiments

# %% [markdown]
# ## Requirements
# If any import in the next cell fails, run the installation cell below once.

# %%
# %%capture
# !pip install mne seaborn pandas matplotlib scikit-learn tensorflow

# %%
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import mne
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers

from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.utils.class_weight import compute_class_weight
from sklearn.feature_selection import mutual_info_classif

from scipy.signal import welch

plt.style.use('seaborn-v0_8')
sns.set_theme(style='whitegrid')
np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore', category=RuntimeWarning)

# %% [markdown]
# ## Dataset Configuration
# We keep the default chunks small so the notebook stays interactive. Adjust subject lists, runs, and epoch limits once the pipeline works on your machine.

# %%
from pathlib import Path

CANDIDATES = [
    Path('eeg_motar_imagery_graph'),
    Path('.'),
    Path('..'),
]

DATA_ROOT = None
for candidate in CANDIDATES:
    if (candidate / 'BCI_2a').exists() and (candidate / 'BCI_2b').exists():
        if ((candidate / 'physionet').exists() or (candidate / 'physionet' / 'files').exists()):
            DATA_ROOT = candidate.resolve()
            break

if DATA_ROOT is None:
    raise FileNotFoundError('Could not locate dataset folders. Update CANDIDATES with your paths.')

BCI2A_ROOT = DATA_ROOT / 'BCI_2a'
BCI2B_ROOT = DATA_ROOT / 'BCI_2b'
PHYSIONET_ROOT = (DATA_ROOT / 'physionet' / 'files') if (DATA_ROOT / 'physionet' / 'files').exists() else (DATA_ROOT / 'physionet')

print('Data root resolved to:', DATA_ROOT)
print('BCI2a path:', BCI2A_ROOT)
print('BCI2b path:', BCI2B_ROOT)
print('PhysioNet path:', PHYSIONET_ROOT)

DATASETS = {
    'BCI_2a': {
        'type': 'gdf',
        'root': BCI2A_ROOT,
        'subjects': ['A01', 'A02', 'A03', 'A04', 'A05', 'A06', 'A07', 'A08', 'A09'],
        'runs': ['T'],
        'epoch_tmin': -0.5,
        'epoch_tmax': 4.0,
        'max_epochs_per_run': None,
        'bandpass': (8.0, 30.0),
        'notch': (50.0,),
        'resample_hz': 128,
        'k_min': 5,
        'k_stride': 5,
    },
    'BCI_2b': {
        'type': 'gdf',
        'root': BCI2B_ROOT,
        'subjects': ['B01', 'B02', 'B03', 'B04', 'B05', 'B06', 'B07', 'B08', 'B09'],
        'runs': ['01T', '02T', '03T'],
        'epoch_tmin': -0.5,
        'epoch_tmax': 4.0,
        'max_epochs_per_run': None,
        'bandpass': (8.0, 30.0),
        'notch': (50.0,),
        'resample_hz': 128,
        'k_min': 5,
        'k_stride': 5,
    },
    'PhysioNet': {
        'type': 'edf',
        'root': PHYSIONET_ROOT,
        'subjects': ['S001', 'S002', 'S003'],
        'runs': ['R03', 'R04', 'R07', 'R08'],
        'epoch_tmin': -0.2,
        'epoch_tmax': 4.0,
        'max_epochs_per_run': 60,
        'bandpass': (1.0, 40.0),
        'notch': (50.0,),
        'resample_hz': 200,
        'k_min': 5,
        'k_stride': 5,
    },
}

print('Configured datasets:', ', '.join(DATASETS.keys()))
# Out:
# Data root resolved to: C:\Users\SHIVAPREETHAM ROHITH\Desktop\AI\codebasics-deeplearning\eeg_motar_imagery_graph
# BCI2a path: C:\Users\SHIVAPREETHAM ROHITH\Desktop\AI\codebasics-deeplearning\eeg_motar_imagery_graph\BCI_2a
# BCI2b path: C:\Users\SHIVAPREETHAM ROHITH\Desktop\AI\codebasics-deeplearning\eeg_motar_imagery_graph\BCI_2b
# PhysioNet path: C:\Users\SHIVAPREETHAM ROHITH\Desktop\AI\codebasics-deeplearning\eeg_motar_imagery_graph\physionet\files
# Configured datasets: BCI_2a, BCI_2b, PhysioNet

# %% [markdown]
# ## Helper Utilities

# %%
EVENT_ID_MAP = {
    'BCI_2a': {
        'left_hand': ['769', '1'],
        'right_hand': ['770', '2'],
        'foot': ['771', '3'],
        'tongue': ['772', '4'],
    },
    'BCI_2b': {
        'left_hand': ['769', '1'],
        'right_hand': ['770', '2'],
    },
    'PhysioNet': {
        'left_fist': ['T1'],
        'right_fist': ['T2'],
        'both_fists': ['T3'],
        'both_feet': ['T4'],
    },
}


def match_event_id(dataset_name, annotation_key):
    for label, keys in EVENT_ID_MAP[dataset_name].items():
        if annotation_key in keys or annotation_key.strip() in keys:
            return label
        if annotation_key.startswith('T') and annotation_key in keys:
            return label
    return None


def load_gdf_chunk(config, dataset_name):
    data_blocks = []
    label_blocks = []
    rows = []
    info = None

    for subject in config['subjects']:
        for run_suffix in config['runs']:
            file_name = f"{subject}{run_suffix}.gdf"
            file_path = config['root'] / file_name
            if not file_path.exists():
                print(f"[skip] Missing {file_path}")
                continue

            raw = mne.io.read_raw_gdf(file_path, preload=True, verbose=False)
            notch = config.get('notch')
            if notch:
                raw.notch_filter(notch, verbose=False)
            if config.get('bandpass') is not None:
                raw.filter(config['bandpass'][0], config['bandpass'][1], fir_design='firwin', verbose=False)

            events, event_id = mne.events_from_annotations(raw, verbose=False)
            selected_ids = {}
            for key, code in event_id.items():
                label = match_event_id(dataset_name, key)
                if label is not None:
                    selected_ids[label] = code

            if not selected_ids:
                print(f"[skip] No MI markers in {file_name}")
                continue

            picks = mne.pick_types(raw.info, meg=False, eeg=True, exclude='bads')
            epochs = mne.Epochs(
                raw,
                events,
                event_id=selected_ids,
                tmin=config['epoch_tmin'],
                tmax=config['epoch_tmax'],
                baseline=None,
                preload=True,
                picks=picks,
                verbose=False,
            )

            epochs.apply_baseline((None, 0))
            resample_hz = config.get('resample_hz')
            if resample_hz:
                epochs.resample(resample_hz, npad='auto')
                epochs.apply_baseline((None, 0))

            if config.get('max_epochs_per_run') is not None:
                epochs = epochs[: config['max_epochs_per_run']]

            data_blocks.append(epochs.get_data())
            inverse_event_id = {v: k for k, v in epochs.event_id.items()}
            epoch_labels = [inverse_event_id[event_code] for event_code in epochs.events[:, 2]]
            label_blocks.extend(epoch_labels)
            rows.extend({
                'subject': subject,
                'run': run_suffix,
                'label': lbl,
            } for lbl in epoch_labels)

            if info is None:
                info = epochs.info

            print(f"[loaded] {dataset_name}: {subject}{run_suffix} -> {len(epoch_labels)} epochs")

    if not data_blocks:
        raise RuntimeError(f"No data loaded for {dataset_name}. Check config and files.")

    data = np.concatenate(data_blocks, axis=0)
    metadata = pd.DataFrame(rows)
    labels = np.array(label_blocks)
    return data, labels, metadata, info


def load_physionet_chunk(config):
    data_blocks = []
    label_blocks = []
    rows = []
    info = None

    for subject in config['subjects']:
        subject_root = config['root'] / subject
        if not subject_root.exists():
            print(f"[skip] Missing {subject_root}")
            continue

        for run in config['runs']:
            file_path = subject_root / f"{subject}{run}.edf"
            if not file_path.exists():
                print(f"[skip] Missing {file_path}")
                continue

            raw = mne.io.read_raw_edf(file_path, preload=True, verbose=False, stim_channel=None)
            notch = config.get('notch')
            if notch:
                raw.notch_filter(notch, verbose=False)
            if config.get('bandpass') is not None:
                raw.filter(config['bandpass'][0], config['bandpass'][1], fir_design='firwin', verbose=False)

            events, event_id = mne.events_from_annotations(raw, verbose=False)
            selected_ids = {}
            for key, code in event_id.items():
                label = match_event_id('PhysioNet', key)
                if label is not None:
                    selected_ids[label] = code

            if not selected_ids:
                print(f"[skip] No motor imagery markers in {file_path.name}")
                continue

            picks = mne.pick_types(raw.info, meg=False, eeg=True, exclude='bads')
            epochs = mne.Epochs(
                raw,
                events,
                event_id=selected_ids,
                tmin=config['epoch_tmin'],
                tmax=config['epoch_tmax'],
                baseline=None,
                preload=True,
                picks=picks,
                verbose=False,
            )

            epochs.apply_baseline((None, 0))
            resample_hz = config.get('resample_hz')
            if resample_hz:
                epochs.resample(resample_hz, npad='auto')
                epochs.apply_baseline((None, 0))

            if config.get('max_epochs_per_run') is not None:
                epochs = epochs[: config['max_epochs_per_run']]

            data_blocks.append(epochs.get_data())
            inverse_event_id = {v: k for k, v in epochs.event_id.items()}
            epoch_labels = [inverse_event_id[event_code] for event_code in epochs.events[:, 2]]
            label_blocks.extend(epoch_labels)
            rows.extend({
                'subject': subject,
                'run': run,
                'label': lbl,
            } for lbl in epoch_labels)

            if info is None:
                info = epochs.info

            print(f"[loaded] PhysioNet: {subject}{run} -> {len(epoch_labels)} epochs")

    if not data_blocks:
        raise RuntimeError('No data loaded for PhysioNet. Check config and files.')

    data = np.concatenate(data_blocks, axis=0)
    metadata = pd.DataFrame(rows)
    labels = np.array(label_blocks)
    return data, labels, metadata, info

# %%
import numpy as np

def standardise_and_split(X, labels, dataset_name=None, selected_indices=None):
    if selected_indices is not None:
        X = X[:, selected_indices, :]
    label_encoder = LabelEncoder()
    y_int = label_encoder.fit_transform(labels)
    y_cat = keras.utils.to_categorical(y_int)

    n_epochs, n_channels, n_times = X.shape
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X.reshape(n_epochs, -1)).reshape(n_epochs, n_channels, n_times).astype(np.float32)

    X_train, X_val, y_train, y_val, y_train_int, y_val_int = train_test_split(
        X_scaled,
        y_cat,
        y_int,
        test_size=0.2,
        stratify=y_int,
        random_state=42,
    )

    if dataset_name in {'BCI_2a', 'BCI_2b'}:
        noise_scale = 0.02 if dataset_name == 'BCI_2a' else 0.015
        rng = np.random.default_rng(42)
        noise = rng.normal(0.0, noise_scale, size=X_train.shape).astype(np.float32)
        X_train = np.concatenate([X_train, X_train + noise], axis=0)
        y_train = np.concatenate([y_train, y_train], axis=0)
        y_train_int = np.concatenate([y_train_int, y_train_int], axis=0)
        shuffle_idx = np.random.permutation(X_train.shape[0])
        X_train = X_train[shuffle_idx].astype(np.float32)
        y_train = y_train[shuffle_idx]
        y_train_int = y_train_int[shuffle_idx]

    classes = np.unique(y_train_int)
    weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_train_int)
    class_weights = {int(c): float(w) for c, w in zip(classes, weights)}

    return {
        'X_train': X_train.astype(np.float32),
        'X_val': X_val.astype(np.float32),
        'y_train': y_train,
        'y_val': y_val,
        'y_train_int': y_train_int,
        'y_val_int': y_val_int,
        'label_encoder': label_encoder,
        'scaler': scaler,
        'class_weights': class_weights,
        'selected_indices': selected_indices,
    }


def compute_graph_matrices(X_train):
    n_epochs, n_channels, n_times = X_train.shape
    flattened = X_train.transpose(1, 0, 2).reshape(n_channels, -1)
    corr = np.corrcoef(flattened)
    adjacency = np.abs(corr)
    np.fill_diagonal(adjacency, 1.0)
    degree = np.sum(adjacency, axis=1)
    degree_inv_sqrt = np.diag(1.0 / np.sqrt(degree + 1e-6))
    laplacian = np.eye(n_channels) - degree_inv_sqrt @ adjacency @ degree_inv_sqrt
    lambda_max = np.linalg.eigvalsh(laplacian)[-1]
    laplacian_rescaled = (2.0 / lambda_max) * laplacian - np.eye(n_channels)
    return adjacency.astype(np.float32), laplacian_rescaled.astype(np.float32)


def _minmax_normalise(scores):
    scores = np.asarray(scores, dtype=np.float64)
    if np.allclose(scores.max(), scores.min()):
        return np.zeros_like(scores)
    return (scores - scores.min()) / (scores.max() - scores.min())


def compute_channel_ranking(X_train, y_train_int, adjacency, alpha=0.6):
    degree_scores = adjacency.sum(axis=1)
    channel_features = X_train.mean(axis=-1)
    mi_scores = mutual_info_classif(channel_features, y_train_int, random_state=42)
    degree_norm = _minmax_normalise(degree_scores)
    mi_norm = _minmax_normalise(mi_scores)
    combined = alpha * degree_norm + (1 - alpha) * mi_norm
    ranking = list(np.argsort(combined)[::-1])
    score_dict = {
        'degree': degree_scores.tolist(),
        'mutual_info': mi_scores.tolist(),
        'combined': combined.tolist(),
    }
    return ranking, score_dict


def generate_k_list(channel_count, k_min=5, stride=5):
    if channel_count <= k_min:
        return [channel_count]
    k_values = list(range(k_min, channel_count + 1, stride))
    if k_values[-1] != channel_count:
        k_values.append(channel_count)
    return k_values


def prepare_dataset_view(base_bundle, k):
    selected = base_bundle['channel_rankings'][:k]
    prep = standardise_and_split(base_bundle['X_raw'], base_bundle['labels'], dataset_name=base_bundle['name'], selected_indices=selected)
    adjacency, laplacian = compute_graph_matrices(prep['X_train'])
    channel_names = [base_bundle['channel_names'][idx] for idx in selected]
    return {
        'name': base_bundle['name'],
        'config': base_bundle['config'],
        'prep': prep,
        'adjacency': adjacency,
        'laplacian': laplacian,
        'channel_names': channel_names,
        'selected_indices': selected,
        'sfreq': base_bundle.get('sfreq'),
        'k': k,
    }

# %% [markdown]
# ## Load and Prepare Datasets

# %%
dataset_store = {}
dataset_summaries = []

for name, cfg in DATASETS.items():
    print(f"=== Loading {name} ===")
    if name == 'PhysioNet':
        X_raw, labels, meta_df, info = load_physionet_chunk(cfg)
    else:
        X_raw, labels, meta_df, info = load_gdf_chunk(cfg, name)

    base_prep = standardise_and_split(X_raw, labels, dataset_name=name)
    adjacency, laplacian = compute_graph_matrices(base_prep['X_train'])
    channel_rankings, ranking_scores = compute_channel_ranking(base_prep['X_train'], base_prep['y_train_int'], adjacency)
    k_candidates = generate_k_list(len(channel_rankings), cfg.get('k_min', 5), cfg.get('k_stride', 5))
    sfreq = cfg.get('resample_hz', getattr(info, "sfreq", None))

    dataset_store[name] = {
        'name': name,
        'config': cfg,
        'X_raw': X_raw,
        'labels': labels,
        'meta': meta_df,
        'info': info,
        'channel_names': info['ch_names'],
        'channel_rankings': channel_rankings,
        'ranking_scores': ranking_scores,
        'k_candidates': k_candidates,
        'sfreq': sfreq,
        'base_prep': base_prep,
        'base_adjacency': adjacency,
        'base_laplacian': laplacian,
    }

    dataset_summaries.append({
        'dataset': name,
        'epochs': X_raw.shape[0],
        'channels': X_raw.shape[1],
        'time_points': X_raw.shape[2],
        'classes': sorted(set(labels)),
    })

summary_df = pd.DataFrame(dataset_summaries)
display(summary_df)
# Out:
# === Loading BCI_2a ===
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2a: A01T -> 288 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2a: A02T -> 288 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2a: A03T -> 288 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2a: A04T -> 288 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2a: A05T -> 288 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2a: A06T -> 288 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2a: A07T -> 288 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2a: A08T -> 288 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2a: A09T -> 288 epochs
# === Loading BCI_2b ===
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0101T -> 120 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0102T -> 120 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0103T -> 160 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0201T -> 120 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0202T -> 120 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0203T -> 160 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0301T -> 120 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0302T -> 120 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0303T -> 160 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0401T -> 120 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0402T -> 140 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0403T -> 160 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0501T -> 120 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0502T -> 140 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0503T -> 160 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0601T -> 120 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0602T -> 120 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0603T -> 160 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0701T -> 120 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0702T -> 120 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0703T -> 160 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0801T -> 160 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0802T -> 120 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0803T -> 160 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0901T -> 120 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0902T -> 120 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] BCI_2b: B0903T -> 160 epochs
# === Loading PhysioNet ===
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] PhysioNet: S001R03 -> 15 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] PhysioNet: S001R04 -> 15 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] PhysioNet: S001R07 -> 15 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] PhysioNet: S001R08 -> 15 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] PhysioNet: S002R03 -> 15 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] PhysioNet: S002R04 -> 15 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] PhysioNet: S002R07 -> 15 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] PhysioNet: S002R08 -> 15 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] PhysioNet: S003R03 -> 15 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] PhysioNet: S003R04 -> 15 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] PhysioNet: S003R07 -> 15 epochs
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# [loaded] PhysioNet: S003R08 -> 15 epochs
#      dataset  epochs  channels  time_points  \
# 0     BCI_2a    2592        25          577
# 1     BCI_2b    3680         6          577
# 2  PhysioNet     180        64          841
#
#                                  classes
# 0  [foot, left_hand, right_hand, tongue]
# 1                [left_hand, right_hand]
# 2                [left_fist, right_fist]

# %% [markdown]
# ## Exploratory Analysis

# %%
for name, bundle in dataset_store.items():
    print(f"--- EDA: {name} ---")
    plot_label_distribution(bundle['meta'], f"{name} - Label counts")
    plot_run_distribution(bundle['meta'], f"{name} - Counts by run")
    plot_sample_trial(bundle['X_raw'], bundle['labels'], bundle['channel_names'],
                      bundle['config']['epoch_tmin'], bundle['config']['epoch_tmax'],
                      f"{name} sample trial")
    plot_channel_correlation(bundle['X_raw'], bundle['channel_names'], f"{name} channel correlation")
# Out:
# --- EDA: BCI_2a ---
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 for name, bundle in dataset_store.items():
#       2     print(f"--- EDA: {name} ---")
# ----> 3     plot_label_distribution(bundle['meta'], f"{name} - Label counts")
#       4     plot_run_distribution(bundle['meta'], f"{name} - Counts by run")
#       5     plot_sample_trial(bundle['X_raw'], bundle['labels'], bundle['channel_names'],
#       6                       bundle['config']['epoch_tmin'], bundle['config']['epoch_tmax'],
#       7                       f"{name} sample trial")
#
# NameError: name 'plot_label_distribution' is not defined

# %% [markdown]
# ## Model Definitions (CNN and Graph-Augmented)

# %%
def create_cnn(input_shape, num_classes, optimizer=None, loss_fn=None):
    inputs = layers.Input(shape=input_shape)
    x = layers.Permute((2, 1))(inputs)

    x = layers.Conv1D(64, kernel_size=25, padding='same', activation=None,
                      kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('elu')(x)
    x = layers.SpatialDropout1D(0.2)(x)

    x = layers.SeparableConv1D(128, kernel_size=15, padding='same', activation=None,
                               depthwise_regularizer=regularizers.l2(1e-4),
                               pointwise_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('elu')(x)
    x = layers.MaxPooling1D(pool_size=2)(x)
    x = layers.SpatialDropout1D(0.25)(x)

    x = layers.Conv1D(256, kernel_size=9, padding='same', activation=None,
                      kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('elu')(x)
    x = layers.GlobalAveragePooling1D()(x)

    x = layers.Dense(128, activation='elu', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(64, activation='elu', kernel_regularizer=regularizers.l2(1e-4))(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = keras.Model(inputs=inputs, outputs=outputs, name='cnn_baseline')
    if optimizer is None:
        optimizer = keras.optimizers.Adam(learning_rate=1e-3, clipnorm=1.0)
    if loss_fn is None:
        loss_fn = keras.losses.CategoricalCrossentropy(label_smoothing=0.02)
    model.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy'])
    return model


class ChebyshevGraphConv(layers.Layer):
    def __init__(self, num_filters, K=3, **kwargs):
        super().__init__(**kwargs)
        self.num_filters = num_filters
        self.K = K

    def build(self, input_shape):
        input_dim = input_shape[0][-1]
        self.theta = [
            self.add_weight(shape=(input_dim, self.num_filters), initializer='glorot_uniform', name=f"theta_{k}")
            for k in range(self.K)
        ]
        super().build(input_shape)

    def call(self, inputs):
        x, laplacian = inputs
        laplacian = tf.cast(laplacian, dtype=x.dtype)
        tx_0 = x
        tx_1 = tf.matmul(laplacian, x)
        outputs = tf.matmul(tx_0, self.theta[0])
        if self.K > 1:
            outputs += tf.matmul(tx_1, self.theta[1])
        for k in range(2, self.K):
            tx_2 = 2.0 * tf.matmul(laplacian, tx_1) - tx_0
            outputs += tf.matmul(tx_2, self.theta[k])
            tx_0, tx_1 = tx_1, tx_2
        return outputs


def create_gcn(input_shape, num_classes, laplacian, optimizer=None, loss_fn=None):
    inputs = layers.Input(shape=input_shape)
    x = layers.Permute((2, 1))(inputs)

    x = layers.Conv1D(64, kernel_size=25, padding='same', activation=None,
                      kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('elu')(x)
    x = layers.MaxPooling1D(pool_size=2)(x)
    x = layers.Dropout(0.35)(x)

    x = layers.Conv1D(128, kernel_size=15, padding='same', activation=None,
                      kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('elu')(x)
    x = layers.GlobalAveragePooling1D()(x)
    cnn_features = layers.Dropout(0.35)(x)

    channel_input = layers.Input(shape=input_shape)
    channel_mean = layers.Lambda(lambda tensor: tf.reduce_mean(tensor, axis=-1, keepdims=True))(channel_input)
    channel_std = layers.Lambda(lambda tensor: tf.math.reduce_std(tensor, axis=-1, keepdims=True))(channel_input)
    channel_logvar = layers.Lambda(lambda tensor: tf.math.log(tf.math.reduce_variance(tensor, axis=-1, keepdims=True) + 1e-6))(channel_input)
    channel_ptp = layers.Lambda(lambda tensor: tf.reduce_max(tensor, axis=-1, keepdims=True) - tf.reduce_min(tensor, axis=-1, keepdims=True))(channel_input)
    channel_stack = layers.Concatenate(axis=-1)([channel_mean, channel_std, channel_logvar, channel_ptp])

    laplacian_tensor = tf.constant(laplacian, dtype=tf.float32)
    graph_features = ChebyshevGraphConv(128, K=3)([channel_stack, laplacian_tensor])
    graph_features = layers.Activation('elu')(graph_features)
    graph_features = layers.Flatten()(graph_features)
    graph_features = layers.BatchNormalization()(graph_features)
    graph_features = layers.Dropout(0.4)(graph_features)

    combined = layers.Concatenate()([cnn_features, graph_features])
    combined = layers.Dense(160, activation='elu', kernel_regularizer=regularizers.l2(1e-4))(combined)
    combined = layers.Dropout(0.5)(combined)
    combined = layers.Dense(96, activation='elu', kernel_regularizer=regularizers.l2(1e-4))(combined)
    outputs = layers.Dense(num_classes, activation='softmax')(combined)

    model = keras.Model(inputs=[inputs, channel_input], outputs=outputs, name='graph_augmented')
    if optimizer is None:
        optimizer = keras.optimizers.Adam(learning_rate=1e-3, clipnorm=5.0)
    if loss_fn is None:
        loss_fn = keras.losses.CategoricalCrossentropy(label_smoothing=0.02)
    model.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy'])
    return model


class MetricsCallback(keras.callbacks.Callback):
    def __init__(self):
        super().__init__()
        self.history = {
            'loss': [],
            'accuracy': [],
            'val_loss': [],
            'val_accuracy': [],
        }
        self.best_val_accuracy = 0.0

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        for key in self.history:
            self.history[key].append(logs.get(key))
        if logs.get('val_accuracy', 0.0) > self.best_val_accuracy:
            self.best_val_accuracy = logs['val_accuracy']


def train_models(bundle, epochs=35, batch_size=32, label_smoothing=0.02):
    input_shape = (bundle['prep']['X_train'].shape[1], bundle['prep']['X_train'].shape[2])
    num_classes = bundle['prep']['y_train'].shape[1]
    laplacian = bundle['laplacian']
    class_weights = bundle['prep']['class_weights']
    label_encoder = bundle['prep']['label_encoder']

    cnn = create_cnn(input_shape, num_classes,
                    optimizer=keras.optimizers.Adam(learning_rate=1e-3, clipnorm=1.0),
                    loss_fn=keras.losses.CategoricalCrossentropy(label_smoothing=label_smoothing))
    gcn = create_gcn(input_shape, num_classes, laplacian,
                    optimizer=keras.optimizers.Adam(learning_rate=1e-3, clipnorm=5.0),
                    loss_fn=keras.losses.CategoricalCrossentropy(label_smoothing=label_smoothing))

    cnn_cb = MetricsCallback()
    gcn_cb = MetricsCallback()

    cnn_callbacks = [
        cnn_cb,
        keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=4, min_lr=1e-5, verbose=1),
        keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True),
    ]
    gcn_callbacks = [
        gcn_cb,
        keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, min_lr=1e-6, verbose=1),
        keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=12, restore_best_weights=True),
    ]

    cnn_history = cnn.fit(
        bundle['prep']['X_train'],
        bundle['prep']['y_train'],
        validation_data=(bundle['prep']['X_val'], bundle['prep']['y_val']),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=cnn_callbacks,
        class_weight=class_weights,
        verbose=2,
    )

    gcn_history = gcn.fit(
        [bundle['prep']['X_train'], bundle['prep']['X_train']],
        bundle['prep']['y_train'],
        validation_data=([bundle['prep']['X_val'], bundle['prep']['X_val']], bundle['prep']['y_val']),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=gcn_callbacks,
        class_weight=class_weights,
        verbose=2,
    )

    cnn_eval = cnn.evaluate(bundle['prep']['X_val'], bundle['prep']['y_val'], verbose=0)
    gcn_eval = gcn.evaluate([bundle['prep']['X_val'], bundle['prep']['X_val']], bundle['prep']['y_val'], verbose=0)

    y_val_true = bundle['prep']['y_val_int']
    cnn_probs = cnn.predict(bundle['prep']['X_val'], verbose=0)
    cnn_preds = np.argmax(cnn_probs, axis=1)
    gcn_probs = gcn.predict([bundle['prep']['X_val'], bundle['prep']['X_val']], verbose=0)
    gcn_preds = np.argmax(gcn_probs, axis=1)

    cnn_scores = {
        'accuracy': float(accuracy_score(y_val_true, cnn_preds)),
        'precision': float(precision_score(y_val_true, cnn_preds, average='macro', zero_division=0)),
        'recall': float(recall_score(y_val_true, cnn_preds, average='macro', zero_division=0)),
        'f1': float(f1_score(y_val_true, cnn_preds, average='macro', zero_division=0)),
    }
    gcn_scores = {
        'accuracy': float(accuracy_score(y_val_true, gcn_preds)),
        'precision': float(precision_score(y_val_true, gcn_preds, average='macro', zero_division=0)),
        'recall': float(recall_score(y_val_true, gcn_preds, average='macro', zero_division=0)),
        'f1': float(f1_score(y_val_true, gcn_preds, average='macro', zero_division=0)),
    }

    target_names = list(label_encoder.classes_)
    cnn_report = classification_report(
        label_encoder.inverse_transform(y_val_true),
        label_encoder.inverse_transform(cnn_preds),
        target_names=target_names,
        output_dict=True,
        zero_division=0,
    )
    gcn_report = classification_report(
        label_encoder.inverse_transform(y_val_true),
        label_encoder.inverse_transform(gcn_preds),
        target_names=target_names,
        output_dict=True,
        zero_division=0,
    )

    return {
        'cnn_model': cnn,
        'gcn_model': gcn,
        'cnn_history': cnn_history.history,
        'gcn_history': gcn_history.history,
        'cnn_metrics': cnn_eval,
        'gcn_metrics': gcn_eval,
        'cnn_scores': cnn_scores,
        'gcn_scores': gcn_scores,
        'cnn_report': cnn_report,
        'gcn_report': gcn_report,
        'cnn_predictions': cnn_preds,
        'gcn_predictions': gcn_preds,
        'cnn_probabilities': cnn_probs,
        'gcn_probabilities': gcn_probs,
    }

# %% [markdown]
# ## Training Loop
# Set  to  when you have the dependencies ready and want to run the models. The default keeps the notebook quick to open.

# %%
RUN_TRAINING = True
EPOCHS = 35
BATCH_SIZE = 32

TRAINING_SCHEDULE = {
    'BCI_2a': {'epochs': 70, 'batch_size': 64},
    'BCI_2b': {'epochs': 50, 'batch_size': 64},
    'PhysioNet': {'epochs': 45, 'batch_size': 32},
}


results = []
model_registry = {}
reports_registry = {}

for name, base_bundle in dataset_store.items():
    print(f'>>> Dataset: {name}')
    if not RUN_TRAINING:
        print('Training skipped. Set RUN_TRAINING=True to execute.')
        continue

    schedule = TRAINING_SCHEDULE.get(name, {'epochs': EPOCHS, 'batch_size': BATCH_SIZE})
    model_registry[name] = {}
    reports_registry[name] = {}
    evaluated_k = []
    best_gcn = {'accuracy': -np.inf, 'k': None}

    for k in base_bundle['k_candidates']:
        view = prepare_dataset_view(base_bundle, k)
        evaluated_k.append(k)
        training_output = train_models(view, epochs=schedule['epochs'], batch_size=schedule['batch_size'])
        training_output['k'] = k
        training_output['selected_indices'] = view['selected_indices']
        model_registry[name][k] = training_output
        reports_registry[name][k] = {
            'CNN': training_output['cnn_report'],
            'GCN': training_output['gcn_report'],
        }

        results.extend([
            {
                'dataset': name,
                'k': k,
                'model': 'CNN',
                'loss': float(training_output['cnn_metrics'][0]),
                **training_output['cnn_scores'],
            },
            {
                'dataset': name,
                'k': k,
                'model': 'GCN',
                'loss': float(training_output['gcn_metrics'][0]),
                **training_output['gcn_scores'],
            },
        ])

        gcn_acc = training_output['gcn_scores']['accuracy']
        if gcn_acc > best_gcn['accuracy']:
            best_gcn = {'accuracy': gcn_acc, 'k': k, 'scores': training_output['gcn_scores']}

    print(f"Best GCN accuracy for {name}: {best_gcn['accuracy']*100:.2f}% at k={best_gcn['k']}")

if results:
    results_df = pd.DataFrame(results).sort_values(['dataset', 'k', 'model']).reset_index(drop=True)
    display(results_df)
else:
    print('No results captured yet.')
# Out:
# >>> Dataset: BCI_2a
# Epoch 1/70
# 65/65 - 46s - 706ms/step - accuracy: 0.2605 - loss: 1.5127 - val_accuracy: 0.2505 - val_loss: 1.4473 - learning_rate: 0.0010
# Epoch 2/70
# 65/65 - 40s - 622ms/step - accuracy: 0.2832 - loss: 1.4403 - val_accuracy: 0.2620 - val_loss: 1.4582 - learning_rate: 0.0010
# Epoch 3/70
# 65/65 - 41s - 631ms/step - accuracy: 0.2947 - loss: 1.4320 - val_accuracy: 0.2486 - val_loss: 1.4734 - learning_rate: 0.0010
# Epoch 4/70
# 65/65 - 42s - 641ms/step - accuracy: 0.3041 - loss: 1.4196 - val_accuracy: 0.2697 - val_loss: 1.4701 - learning_rate: 0.0010
# Epoch 5/70
# 65/65 - 41s - 627ms/step - accuracy: 0.3181 - loss: 1.4145 - val_accuracy: 0.2813 - val_loss: 1.4369 - learning_rate: 0.0010
# Epoch 6/70
# 65/65 - 41s - 628ms/step - accuracy: 0.3435 - loss: 1.3950 - val_accuracy: 0.3661 - val_loss: 1.4197 - learning_rate: 0.0010
# Epoch 7/70
# 65/65 - 41s - 630ms/step - accuracy: 0.3531 - loss: 1.3802 - val_accuracy: 0.3410 - val_loss: 1.3817 - learning_rate: 0.0010
# Epoch 8/70
# 65/65 - 41s - 635ms/step - accuracy: 0.3719 - loss: 1.3694 - val_accuracy: 0.3854 - val_loss: 1.3530 - learning_rate: 0.0010
# Epoch 9/70
# 65/65 - 41s - 636ms/step - accuracy: 0.3857 - loss: 1.3567 - val_accuracy: 0.3931 - val_loss: 1.3440 - learning_rate: 0.0010
# Epoch 10/70
# 65/65 - 41s - 623ms/step - accuracy: 0.3910 - loss: 1.3441 - val_accuracy: 0.3969 - val_loss: 1.3231 - learning_rate: 0.0010
# Epoch 11/70
# 65/65 - 42s - 646ms/step - accuracy: 0.3910 - loss: 1.3404 - val_accuracy: 0.3603 - val_loss: 1.3804 - learning_rate: 0.0010
# Epoch 12/70
# 65/65 - 41s - 636ms/step - accuracy: 0.4018 - loss: 1.3376 - val_accuracy: 0.3680 - val_loss: 1.3457 - learning_rate: 0.0010
# Epoch 13/70
# 65/65 - 46s - 713ms/step - accuracy: 0.4122 - loss: 1.3190 - val_accuracy: 0.3642 - val_loss: 1.3325 - learning_rate: 0.0010
# Epoch 14/70
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 65/65 - 43s - 662ms/step - accuracy: 0.4083 - loss: 1.3253 - val_accuracy: 0.3834 - val_loss: 1.3171 - learning_rate: 0.0010
# Epoch 15/70
# 65/65 - 42s - 653ms/step - accuracy: 0.4112 - loss: 1.3065 - val_accuracy: 0.4316 - val_loss: 1.2934 - learning_rate: 5.0000e-04
# Epoch 16/70
# 65/65 - 42s - 651ms/step - accuracy: 0.4185 - loss: 1.2964 - val_accuracy: 0.4200 - val_loss: 1.2913 - learning_rate: 5.0000e-04
# Epoch 17/70
# 65/65 - 42s - 649ms/step - accuracy: 0.4221 - loss: 1.2934 - val_accuracy: 0.4027 - val_loss: 1.3018 - learning_rate: 5.0000e-04
# Epoch 18/70
# 65/65 - 43s - 662ms/step - accuracy: 0.4276 - loss: 1.2889 - val_accuracy: 0.4008 - val_loss: 1.2907 - learning_rate: 5.0000e-04
# Epoch 19/70
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 65/65 - 43s - 656ms/step - accuracy: 0.4329 - loss: 1.2794 - val_accuracy: 0.4200 - val_loss: 1.2865 - learning_rate: 5.0000e-04
# Epoch 20/70
# 65/65 - 44s - 683ms/step - accuracy: 0.4296 - loss: 1.2721 - val_accuracy: 0.4316 - val_loss: 1.2741 - learning_rate: 2.5000e-04
# Epoch 21/70
# 65/65 - 42s - 650ms/step - accuracy: 0.4373 - loss: 1.2667 - val_accuracy: 0.4220 - val_loss: 1.2687 - learning_rate: 2.5000e-04
# Epoch 22/70
# 65/65 - 40s - 619ms/step - accuracy: 0.4440 - loss: 1.2563 - val_accuracy: 0.4412 - val_loss: 1.2616 - learning_rate: 2.5000e-04
# Epoch 23/70
# 65/65 - 41s - 636ms/step - accuracy: 0.4501 - loss: 1.2466 - val_accuracy: 0.4547 - val_loss: 1.2556 - learning_rate: 2.5000e-04
# Epoch 24/70
# 65/65 - 43s - 661ms/step - accuracy: 0.4585 - loss: 1.2502 - val_accuracy: 0.4393 - val_loss: 1.2546 - learning_rate: 2.5000e-04
# Epoch 25/70
# 65/65 - 42s - 647ms/step - accuracy: 0.4455 - loss: 1.2489 - val_accuracy: 0.4412 - val_loss: 1.2549 - learning_rate: 2.5000e-04
# Epoch 26/70
# 65/65 - 42s - 651ms/step - accuracy: 0.4532 - loss: 1.2401 - val_accuracy: 0.4489 - val_loss: 1.2522 - learning_rate: 2.5000e-04
# Epoch 27/70
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 65/65 - 43s - 660ms/step - accuracy: 0.4556 - loss: 1.2427 - val_accuracy: 0.4355 - val_loss: 1.2566 - learning_rate: 2.5000e-04
# Epoch 28/70
# 65/65 - 42s - 648ms/step - accuracy: 0.4686 - loss: 1.2288 - val_accuracy: 0.4451 - val_loss: 1.2396 - learning_rate: 1.2500e-04
# Epoch 29/70
# 65/65 - 44s - 679ms/step - accuracy: 0.4561 - loss: 1.2236 - val_accuracy: 0.4663 - val_loss: 1.2348 - learning_rate: 1.2500e-04
# Epoch 30/70
# 65/65 - 42s - 641ms/step - accuracy: 0.4597 - loss: 1.2253 - val_accuracy: 0.4489 - val_loss: 1.2374 - learning_rate: 1.2500e-04
# Epoch 31/70
# 65/65 - 81s - 1s/step - accuracy: 0.4674 - loss: 1.2268 - val_accuracy: 0.4509 - val_loss: 1.2352 - learning_rate: 1.2500e-04
# Epoch 32/70
# 65/65 - 44s - 684ms/step - accuracy: 0.4689 - loss: 1.2229 - val_accuracy: 0.4586 - val_loss: 1.2317 - learning_rate: 1.2500e-04
# Epoch 33/70
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 65/65 - 44s - 671ms/step - accuracy: 0.4653 - loss: 1.2181 - val_accuracy: 0.4624 - val_loss: 1.2313 - learning_rate: 1.2500e-04
# Epoch 34/70
# 65/65 - 44s - 675ms/step - accuracy: 0.4691 - loss: 1.2183 - val_accuracy: 0.4489 - val_loss: 1.2309 - learning_rate: 6.2500e-05
# Epoch 35/70
# 65/65 - 45s - 690ms/step - accuracy: 0.4665 - loss: 1.2170 - val_accuracy: 0.4644 - val_loss: 1.2262 - learning_rate: 6.2500e-05
# Epoch 36/70
# 65/65 - 47s - 720ms/step - accuracy: 0.4781 - loss: 1.2083 - val_accuracy: 0.4663 - val_loss: 1.2247 - learning_rate: 6.2500e-05
# Epoch 37/70
# 65/65 - 46s - 712ms/step - accuracy: 0.4771 - loss: 1.2123 - val_accuracy: 0.4759 - val_loss: 1.2251 - learning_rate: 6.2500e-05
# Epoch 38/70
# 65/65 - 44s - 670ms/step - accuracy: 0.4846 - loss: 1.2112 - val_accuracy: 0.4566 - val_loss: 1.2269 - learning_rate: 6.2500e-05
# Epoch 39/70
# 65/65 - 42s - 653ms/step - accuracy: 0.4756 - loss: 1.2086 - val_accuracy: 0.4682 - val_loss: 1.2282 - learning_rate: 6.2500e-05
# Epoch 40/70
# 65/65 - 43s - 664ms/step - accuracy: 0.4812 - loss: 1.2109 - val_accuracy: 0.4566 - val_loss: 1.2262 - learning_rate: 6.2500e-05
# Epoch 41/70
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 65/65 - 43s - 667ms/step - accuracy: 0.4699 - loss: 1.2166 - val_accuracy: 0.4682 - val_loss: 1.2232 - learning_rate: 6.2500e-05
# Epoch 42/70
# 65/65 - 42s - 644ms/step - accuracy: 0.4754 - loss: 1.2008 - val_accuracy: 0.4663 - val_loss: 1.2221 - learning_rate: 3.1250e-05
# Epoch 43/70
# 65/65 - 42s - 652ms/step - accuracy: 0.4867 - loss: 1.1969 - val_accuracy: 0.4605 - val_loss: 1.2216 - learning_rate: 3.1250e-05
# Epoch 44/70
# 65/65 - 42s - 653ms/step - accuracy: 0.4776 - loss: 1.2081 - val_accuracy: 0.4586 - val_loss: 1.2223 - learning_rate: 3.1250e-05
# Epoch 45/70
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 65/65 - 41s - 628ms/step - accuracy: 0.4807 - loss: 1.2097 - val_accuracy: 0.4624 - val_loss: 1.2222 - learning_rate: 3.1250e-05
# Epoch 46/70
# 65/65 - 41s - 633ms/step - accuracy: 0.4802 - loss: 1.2044 - val_accuracy: 0.4605 - val_loss: 1.2222 - learning_rate: 1.5625e-05
# Epoch 47/70
# 65/65 - 40s - 614ms/step - accuracy: 0.4795 - loss: 1.2025 - val_accuracy: 0.4682 - val_loss: 1.2229 - learning_rate: 1.5625e-05
# Epoch 1/70
# 65/65 - 22s - 333ms/step - accuracy: 0.2668 - loss: 1.8482 - val_accuracy: 0.2505 - val_loss: 1.5330 - learning_rate: 0.0010
# Epoch 2/70
# 65/65 - 14s - 220ms/step - accuracy: 0.2781 - loss: 1.5646 - val_accuracy: 0.2640 - val_loss: 1.4565 - learning_rate: 0.0010
# Epoch 3/70
# 65/65 - 14s - 219ms/step - accuracy: 0.2808 - loss: 1.5152 - val_accuracy: 0.2697 - val_loss: 1.4317 - learning_rate: 0.0010
# Epoch 4/70
# 65/65 - 14s - 222ms/step - accuracy: 0.2906 - loss: 1.4874 - val_accuracy: 0.2987 - val_loss: 1.4301 - learning_rate: 0.0010
# Epoch 5/70
# 65/65 - 14s - 217ms/step - accuracy: 0.3174 - loss: 1.4616 - val_accuracy: 0.3006 - val_loss: 1.4219 - learning_rate: 0.0010
# Epoch 6/70
# 65/65 - 14s - 220ms/step - accuracy: 0.3256 - loss: 1.4415 - val_accuracy: 0.2909 - val_loss: 1.4392 - learning_rate: 0.0010
# Epoch 7/70
# 65/65 - 15s - 223ms/step - accuracy: 0.3430 - loss: 1.4226 - val_accuracy: 0.3256 - val_loss: 1.4102 - learning_rate: 0.0010
# Epoch 8/70
# 65/65 - 14s - 216ms/step - accuracy: 0.3509 - loss: 1.4131 - val_accuracy: 0.3333 - val_loss: 1.4111 - learning_rate: 0.0010
# Epoch 9/70
# 65/65 - 15s - 223ms/step - accuracy: 0.3618 - loss: 1.3825 - val_accuracy: 0.3141 - val_loss: 1.3977 - learning_rate: 0.0010
# Epoch 10/70
# 65/65 - 14s - 214ms/step - accuracy: 0.3751 - loss: 1.3722 - val_accuracy: 0.3218 - val_loss: 1.4046 - learning_rate: 0.0010
# Epoch 11/70
# 65/65 - 14s - 216ms/step - accuracy: 0.3975 - loss: 1.3496 - val_accuracy: 0.3449 - val_loss: 1.3690 - learning_rate: 0.0010
# Epoch 12/70
# 65/65 - 15s - 230ms/step - accuracy: 0.3927 - loss: 1.3451 - val_accuracy: 0.3776 - val_loss: 1.3422 - learning_rate: 0.0010
# Epoch 13/70
# 65/65 - 14s - 219ms/step - accuracy: 0.4173 - loss: 1.3179 - val_accuracy: 0.4008 - val_loss: 1.3402 - learning_rate: 0.0010
# Epoch 14/70
# 65/65 - 14s - 223ms/step - accuracy: 0.4219 - loss: 1.2992 - val_accuracy: 0.3776 - val_loss: 1.3238 - learning_rate: 0.0010
# Epoch 15/70
# 65/65 - 14s - 216ms/step - accuracy: 0.4286 - loss: 1.3061 - val_accuracy: 0.3719 - val_loss: 1.3429 - learning_rate: 0.0010
# Epoch 16/70
# 65/65 - 14s - 215ms/step - accuracy: 0.4436 - loss: 1.2806 - val_accuracy: 0.3622 - val_loss: 1.3406 - learning_rate: 0.0010
# Epoch 17/70
# 65/65 - 15s - 227ms/step - accuracy: 0.4320 - loss: 1.2782 - val_accuracy: 0.3931 - val_loss: 1.3358 - learning_rate: 0.0010
# Epoch 18/70
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 65/65 - 14s - 217ms/step - accuracy: 0.4522 - loss: 1.2677 - val_accuracy: 0.3680 - val_loss: 1.4030 - learning_rate: 0.0010
# Epoch 19/70
# 65/65 - 15s - 232ms/step - accuracy: 0.4674 - loss: 1.2413 - val_accuracy: 0.4297 - val_loss: 1.2837 - learning_rate: 5.0000e-04
# Epoch 20/70
# 65/65 - 14s - 215ms/step - accuracy: 0.4694 - loss: 1.2240 - val_accuracy: 0.4220 - val_loss: 1.2754 - learning_rate: 5.0000e-04
# Epoch 21/70
# 65/65 - 20s - 309ms/step - accuracy: 0.4766 - loss: 1.2223 - val_accuracy: 0.4470 - val_loss: 1.2745 - learning_rate: 5.0000e-04
# Epoch 22/70
# 65/65 - 14s - 223ms/step - accuracy: 0.4725 - loss: 1.2122 - val_accuracy: 0.4143 - val_loss: 1.2908 - learning_rate: 5.0000e-04
# Epoch 23/70
# 65/65 - 20s - 305ms/step - accuracy: 0.4829 - loss: 1.2041 - val_accuracy: 0.4258 - val_loss: 1.2851 - learning_rate: 5.0000e-04
# Epoch 24/70
# 65/65 - 14s - 216ms/step - accuracy: 0.4877 - loss: 1.2004 - val_accuracy: 0.4412 - val_loss: 1.2669 - learning_rate: 5.0000e-04
# Epoch 25/70
# 65/65 - 14s - 222ms/step - accuracy: 0.4872 - loss: 1.1905 - val_accuracy: 0.4239 - val_loss: 1.2758 - learning_rate: 5.0000e-04
# Epoch 26/70
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 65/65 - 14s - 217ms/step - accuracy: 0.4961 - loss: 1.1924 - val_accuracy: 0.4355 - val_loss: 1.2869 - learning_rate: 5.0000e-04
# Epoch 27/70
# 65/65 - 14s - 215ms/step - accuracy: 0.5121 - loss: 1.1686 - val_accuracy: 0.4451 - val_loss: 1.2880 - learning_rate: 2.5000e-04
# Epoch 28/70
# 65/65 - 14s - 217ms/step - accuracy: 0.5123 - loss: 1.1657 - val_accuracy: 0.4258 - val_loss: 1.2623 - learning_rate: 2.5000e-04
# Epoch 29/70
# 65/65 - 14s - 222ms/step - accuracy: 0.5176 - loss: 1.1511 - val_accuracy: 0.4374 - val_loss: 1.2647 - learning_rate: 2.5000e-04
# Epoch 30/70
# 65/65 - 14s - 218ms/step - accuracy: 0.5118 - loss: 1.1521 - val_accuracy: 0.4489 - val_loss: 1.2627 - learning_rate: 2.5000e-04
# Epoch 31/70
# 65/65 - 15s - 225ms/step - accuracy: 0.5123 - loss: 1.1546 - val_accuracy: 0.4489 - val_loss: 1.2473 - learning_rate: 2.5000e-04
# Epoch 32/70
# 65/65 - 14s - 218ms/step - accuracy: 0.5263 - loss: 1.1406 - val_accuracy: 0.4547 - val_loss: 1.2465 - learning_rate: 2.5000e-04
# Epoch 33/70
# 65/65 - 14s - 220ms/step - accuracy: 0.5193 - loss: 1.1493 - val_accuracy: 0.4509 - val_loss: 1.2425 - learning_rate: 2.5000e-04
# Epoch 34/70
# 65/65 - 15s - 226ms/step - accuracy: 0.5166 - loss: 1.1381 - val_accuracy: 0.4624 - val_loss: 1.2492 - learning_rate: 2.5000e-04
# Epoch 35/70
# 65/65 - 14s - 222ms/step - accuracy: 0.5191 - loss: 1.1378 - val_accuracy: 0.4663 - val_loss: 1.2541 - learning_rate: 2.5000e-04
# Epoch 36/70
# 65/65 - 14s - 218ms/step - accuracy: 0.5205 - loss: 1.1335 - val_accuracy: 0.4355 - val_loss: 1.2613 - learning_rate: 2.5000e-04
# Epoch 37/70
# 65/65 - 14s - 216ms/step - accuracy: 0.5347 - loss: 1.1300 - val_accuracy: 0.4509 - val_loss: 1.2632 - learning_rate: 2.5000e-04
# Epoch 38/70
# 65/65 - 15s - 224ms/step - accuracy: 0.5207 - loss: 1.1351 - val_accuracy: 0.4566 - val_loss: 1.2500 - learning_rate: 2.5000e-04
# Epoch 39/70
# 65/65 - 14s - 217ms/step - accuracy: 0.5253 - loss: 1.1269 - val_accuracy: 0.4721 - val_loss: 1.2339 - learning_rate: 2.5000e-04
# Epoch 40/70
# 65/65 - 14s - 217ms/step - accuracy: 0.5311 - loss: 1.1295 - val_accuracy: 0.4586 - val_loss: 1.2598 - learning_rate: 2.5000e-04
# Epoch 41/70
# 65/65 - 15s - 223ms/step - accuracy: 0.5362 - loss: 1.1233 - val_accuracy: 0.4759 - val_loss: 1.2321 - learning_rate: 2.5000e-04
# Epoch 42/70
# 65/65 - 14s - 218ms/step - accuracy: 0.5359 - loss: 1.1232 - val_accuracy: 0.4547 - val_loss: 1.2407 - learning_rate: 2.5000e-04
# Epoch 43/70
# 65/65 - 15s - 224ms/step - accuracy: 0.5260 - loss: 1.1254 - val_accuracy: 0.4759 - val_loss: 1.2332 - learning_rate: 2.5000e-04
# Epoch 44/70
# 65/65 - 15s - 227ms/step - accuracy: 0.5388 - loss: 1.1239 - val_accuracy: 0.4644 - val_loss: 1.2436 - learning_rate: 2.5000e-04
# Epoch 45/70
# 65/65 - 14s - 220ms/step - accuracy: 0.5318 - loss: 1.1256 - val_accuracy: 0.4489 - val_loss: 1.2473 - learning_rate: 2.5000e-04
# Epoch 46/70
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 65/65 - 14s - 217ms/step - accuracy: 0.5420 - loss: 1.1036 - val_accuracy: 0.4663 - val_loss: 1.2426 - learning_rate: 2.5000e-04
# Epoch 47/70
# 65/65 - 14s - 217ms/step - accuracy: 0.5473 - loss: 1.1140 - val_accuracy: 0.4682 - val_loss: 1.2359 - learning_rate: 1.2500e-04
# Epoch 48/70
# 65/65 - 14s - 217ms/step - accuracy: 0.5487 - loss: 1.0967 - val_accuracy: 0.4682 - val_loss: 1.2323 - learning_rate: 1.2500e-04
# Epoch 49/70
# 65/65 - 14s - 222ms/step - accuracy: 0.5557 - loss: 1.0830 - val_accuracy: 0.4663 - val_loss: 1.2335 - learning_rate: 1.2500e-04
# Epoch 50/70
# 65/65 - 14s - 217ms/step - accuracy: 0.5589 - loss: 1.0936 - val_accuracy: 0.4721 - val_loss: 1.2340 - learning_rate: 1.2500e-04
# Epoch 51/70
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 65/65 - 14s - 215ms/step - accuracy: 0.5519 - loss: 1.0934 - val_accuracy: 0.4759 - val_loss: 1.2406 - learning_rate: 1.2500e-04
# Epoch 52/70
# 65/65 - 15s - 229ms/step - accuracy: 0.5531 - loss: 1.0852 - val_accuracy: 0.4701 - val_loss: 1.2340 - learning_rate: 6.2500e-05
# Epoch 53/70
# 65/65 - 14s - 220ms/step - accuracy: 0.5601 - loss: 1.0830 - val_accuracy: 0.4624 - val_loss: 1.2340 - learning_rate: 6.2500e-05
# WARNING:tensorflow:6 out of the last 28 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000254537DCB80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/70
# 65/65 - 47s - 729ms/step - accuracy: 0.2542 - loss: 1.5154 - val_accuracy: 0.2697 - val_loss: 1.4415 - learning_rate: 0.0010
# Epoch 2/70
# 65/65 - 41s - 625ms/step - accuracy: 0.2817 - loss: 1.4498 - val_accuracy: 0.2543 - val_loss: 1.4488 - learning_rate: 0.0010
# Epoch 3/70
# 65/65 - 41s - 637ms/step - accuracy: 0.2911 - loss: 1.4370 - val_accuracy: 0.2967 - val_loss: 1.4419 - learning_rate: 0.0010
# Epoch 4/70
# 65/65 - 41s - 631ms/step - accuracy: 0.3285 - loss: 1.4133 - val_accuracy: 0.3160 - val_loss: 1.4246 - learning_rate: 0.0010
# Epoch 5/70
# 65/65 - 41s - 627ms/step - accuracy: 0.3341 - loss: 1.4020 - val_accuracy: 0.3584 - val_loss: 1.3867 - learning_rate: 0.0010
# Epoch 6/70
# 65/65 - 41s - 624ms/step - accuracy: 0.3567 - loss: 1.3784 - val_accuracy: 0.3487 - val_loss: 1.3743 - learning_rate: 0.0010
# Epoch 7/70
# 65/65 - 40s - 623ms/step - accuracy: 0.3661 - loss: 1.3629 - val_accuracy: 0.3449 - val_loss: 1.3748 - learning_rate: 0.0010
# Epoch 8/70
# 65/65 - 42s - 640ms/step - accuracy: 0.3758 - loss: 1.3636 - val_accuracy: 0.3854 - val_loss: 1.3598 - learning_rate: 0.0010
# Epoch 9/70
# 65/65 - 40s - 620ms/step - accuracy: 0.3825 - loss: 1.3464 - val_accuracy: 0.3410 - val_loss: 1.3990 - learning_rate: 0.0010
# Epoch 10/70
# 65/65 - 41s - 634ms/step - accuracy: 0.3833 - loss: 1.3488 - val_accuracy: 0.3892 - val_loss: 1.3478 - learning_rate: 0.0010
# Epoch 11/70
# 65/65 - 41s - 627ms/step - accuracy: 0.4023 - loss: 1.3250 - val_accuracy: 0.3815 - val_loss: 1.3376 - learning_rate: 0.0010
# Epoch 12/70
# 65/65 - 41s - 631ms/step - accuracy: 0.3982 - loss: 1.3260 - val_accuracy: 0.4085 - val_loss: 1.3158 - learning_rate: 0.0010
# Epoch 13/70
# 65/65 - 41s - 633ms/step - accuracy: 0.4018 - loss: 1.3167 - val_accuracy: 0.3969 - val_loss: 1.3202 - learning_rate: 0.0010
# Epoch 14/70
# 65/65 - 41s - 627ms/step - accuracy: 0.3944 - loss: 1.3222 - val_accuracy: 0.4277 - val_loss: 1.3027 - learning_rate: 0.0010
# Epoch 15/70
# 65/65 - 42s - 639ms/step - accuracy: 0.4228 - loss: 1.3044 - val_accuracy: 0.3911 - val_loss: 1.3261 - learning_rate: 0.0010
# Epoch 16/70
# 65/65 - 40s - 620ms/step - accuracy: 0.4190 - loss: 1.3089 - val_accuracy: 0.4277 - val_loss: 1.3027 - learning_rate: 0.0010
# Epoch 17/70
# 65/65 - 41s - 624ms/step - accuracy: 0.4260 - loss: 1.2947 - val_accuracy: 0.4123 - val_loss: 1.2894 - learning_rate: 0.0010
# Epoch 18/70
# 65/65 - 41s - 628ms/step - accuracy: 0.4163 - loss: 1.2985 - val_accuracy: 0.4335 - val_loss: 1.2799 - learning_rate: 0.0010
# Epoch 19/70
# 65/65 - 41s - 627ms/step - accuracy: 0.4279 - loss: 1.2774 - val_accuracy: 0.4316 - val_loss: 1.2650 - learning_rate: 0.0010
# Epoch 20/70
# 65/65 - 40s - 623ms/step - accuracy: 0.4332 - loss: 1.2824 - val_accuracy: 0.4297 - val_loss: 1.2617 - learning_rate: 0.0010
# Epoch 21/70
# 65/65 - 41s - 637ms/step - accuracy: 0.4366 - loss: 1.2724 - val_accuracy: 0.4258 - val_loss: 1.2638 - learning_rate: 0.0010
# Epoch 22/70
# 65/65 - 40s - 623ms/step - accuracy: 0.4455 - loss: 1.2552 - val_accuracy: 0.4470 - val_loss: 1.2528 - learning_rate: 0.0010
# Epoch 23/70
# 65/65 - 41s - 631ms/step - accuracy: 0.4399 - loss: 1.2530 - val_accuracy: 0.4258 - val_loss: 1.2521 - learning_rate: 0.0010
# Epoch 24/70
# 65/65 - 41s - 630ms/step - accuracy: 0.4416 - loss: 1.2520 - val_accuracy: 0.4470 - val_loss: 1.2444 - learning_rate: 0.0010
# Epoch 25/70
# 65/65 - 41s - 629ms/step - accuracy: 0.4527 - loss: 1.2415 - val_accuracy: 0.4277 - val_loss: 1.2453 - learning_rate: 0.0010
# Epoch 26/70
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 65/65 - 40s - 623ms/step - accuracy: 0.4503 - loss: 1.2407 - val_accuracy: 0.4432 - val_loss: 1.2531 - learning_rate: 0.0010
# Epoch 27/70
# 65/65 - 41s - 626ms/step - accuracy: 0.4679 - loss: 1.2132 - val_accuracy: 0.4489 - val_loss: 1.2299 - learning_rate: 5.0000e-04
# Epoch 28/70
# 65/65 - 41s - 626ms/step - accuracy: 0.4691 - loss: 1.1991 - val_accuracy: 0.4528 - val_loss: 1.2257 - learning_rate: 5.0000e-04
# Epoch 29/70
# 65/65 - 40s - 618ms/step - accuracy: 0.4894 - loss: 1.1860 - val_accuracy: 0.4528 - val_loss: 1.2211 - learning_rate: 5.0000e-04
# Epoch 30/70
# 65/65 - 41s - 632ms/step - accuracy: 0.4814 - loss: 1.1905 - val_accuracy: 0.4566 - val_loss: 1.2278 - learning_rate: 5.0000e-04
# Epoch 31/70
# 65/65 - 40s - 616ms/step - accuracy: 0.4814 - loss: 1.1821 - val_accuracy: 0.4509 - val_loss: 1.2214 - learning_rate: 5.0000e-04
# Epoch 32/70
# 65/65 - 42s - 644ms/step - accuracy: 0.4954 - loss: 1.1784 - val_accuracy: 0.4547 - val_loss: 1.2205 - learning_rate: 5.0000e-04
# Epoch 33/70
# 65/65 - 41s - 630ms/step - accuracy: 0.4879 - loss: 1.1745 - val_accuracy: 0.4663 - val_loss: 1.2183 - learning_rate: 5.0000e-04
# Epoch 34/70
# 65/65 - 40s - 618ms/step - accuracy: 0.4913 - loss: 1.1711 - val_accuracy: 0.4586 - val_loss: 1.2080 - learning_rate: 5.0000e-04
# Epoch 35/70
# 65/65 - 40s - 619ms/step - accuracy: 0.4913 - loss: 1.1662 - val_accuracy: 0.4663 - val_loss: 1.2068 - learning_rate: 5.0000e-04
# Epoch 36/70
# 65/65 - 41s - 626ms/step - accuracy: 0.4925 - loss: 1.1657 - val_accuracy: 0.4470 - val_loss: 1.2153 - learning_rate: 5.0000e-04
# Epoch 37/70
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 65/65 - 41s - 637ms/step - accuracy: 0.4988 - loss: 1.1603 - val_accuracy: 0.4624 - val_loss: 1.2192 - learning_rate: 5.0000e-04
# Epoch 38/70
# 65/65 - 40s - 609ms/step - accuracy: 0.5034 - loss: 1.1489 - val_accuracy: 0.4624 - val_loss: 1.2076 - learning_rate: 2.5000e-04
# Epoch 39/70
# 65/65 - 41s - 632ms/step - accuracy: 0.5010 - loss: 1.1409 - val_accuracy: 0.4586 - val_loss: 1.2039 - learning_rate: 2.5000e-04
# Epoch 40/70
# 65/65 - 41s - 624ms/step - accuracy: 0.5137 - loss: 1.1306 - val_accuracy: 0.4624 - val_loss: 1.1974 - learning_rate: 2.5000e-04
# Epoch 41/70
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 65/65 - 41s - 634ms/step - accuracy: 0.5092 - loss: 1.1309 - val_accuracy: 0.4624 - val_loss: 1.2141 - learning_rate: 2.5000e-04
# Epoch 42/70
# 65/65 - 41s - 632ms/step - accuracy: 0.5316 - loss: 1.1190 - val_accuracy: 0.4605 - val_loss: 1.2046 - learning_rate: 1.2500e-04
# Epoch 43/70
# 65/65 - 40s - 621ms/step - accuracy: 0.5162 - loss: 1.1221 - val_accuracy: 0.4663 - val_loss: 1.1985 - learning_rate: 1.2500e-04
# Epoch 1/70
# 65/65 - 21s - 320ms/step - accuracy: 0.2701 - loss: 2.0885 - val_accuracy: 0.2678 - val_loss: 1.4951 - learning_rate: 0.0010
# Epoch 2/70
# 65/65 - 15s - 225ms/step - accuracy: 0.2824 - loss: 1.6904 - val_accuracy: 0.2717 - val_loss: 1.4421 - learning_rate: 0.0010
# Epoch 3/70
# 65/65 - 15s - 226ms/step - accuracy: 0.2853 - loss: 1.5967 - val_accuracy: 0.2832 - val_loss: 1.4426 - learning_rate: 0.0010
# Epoch 4/70
# 65/65 - 15s - 229ms/step - accuracy: 0.3172 - loss: 1.5350 - val_accuracy: 0.2813 - val_loss: 1.4327 - learning_rate: 0.0010
# Epoch 5/70
# 65/65 - 16s - 238ms/step - accuracy: 0.3331 - loss: 1.4671 - val_accuracy: 0.3083 - val_loss: 1.4161 - learning_rate: 0.0010
# Epoch 6/70
# 65/65 - 15s - 226ms/step - accuracy: 0.3519 - loss: 1.4376 - val_accuracy: 0.2659 - val_loss: 1.5701 - learning_rate: 0.0010
# Epoch 7/70
# 65/65 - 15s - 233ms/step - accuracy: 0.3584 - loss: 1.4359 - val_accuracy: 0.3661 - val_loss: 1.4043 - learning_rate: 0.0010
# Epoch 8/70
# 65/65 - 15s - 230ms/step - accuracy: 0.3647 - loss: 1.4049 - val_accuracy: 0.3102 - val_loss: 1.4170 - learning_rate: 0.0010
# Epoch 9/70
# 65/65 - 15s - 234ms/step - accuracy: 0.3840 - loss: 1.3796 - val_accuracy: 0.3353 - val_loss: 1.3879 - learning_rate: 0.0010
# Epoch 10/70
# 65/65 - 15s - 224ms/step - accuracy: 0.3890 - loss: 1.3643 - val_accuracy: 0.3603 - val_loss: 1.3707 - learning_rate: 0.0010
# Epoch 11/70
# 65/65 - 15s - 224ms/step - accuracy: 0.4040 - loss: 1.3318 - val_accuracy: 0.3719 - val_loss: 1.3755 - learning_rate: 0.0010
# Epoch 12/70
# 65/65 - 15s - 226ms/step - accuracy: 0.4035 - loss: 1.3358 - val_accuracy: 0.3834 - val_loss: 1.3426 - learning_rate: 0.0010
# Epoch 13/70
# 65/65 - 15s - 225ms/step - accuracy: 0.4247 - loss: 1.3035 - val_accuracy: 0.3699 - val_loss: 1.3914 - learning_rate: 0.0010
# Epoch 14/70
# 65/65 - 15s - 224ms/step - accuracy: 0.4247 - loss: 1.2885 - val_accuracy: 0.3757 - val_loss: 1.3924 - learning_rate: 0.0010
# Epoch 15/70
# 65/65 - 15s - 232ms/step - accuracy: 0.4407 - loss: 1.2862 - val_accuracy: 0.3892 - val_loss: 1.3664 - learning_rate: 0.0010
# Epoch 16/70
# 65/65 - 15s - 229ms/step - accuracy: 0.4561 - loss: 1.2668 - val_accuracy: 0.4066 - val_loss: 1.3238 - learning_rate: 0.0010
# Epoch 17/70
# 65/65 - 15s - 226ms/step - accuracy: 0.4583 - loss: 1.2535 - val_accuracy: 0.3873 - val_loss: 1.3787 - learning_rate: 0.0010
# Epoch 18/70
# 65/65 - 15s - 234ms/step - accuracy: 0.4626 - loss: 1.2498 - val_accuracy: 0.3892 - val_loss: 1.3037 - learning_rate: 0.0010
# Epoch 19/70
# 65/65 - 15s - 226ms/step - accuracy: 0.4829 - loss: 1.2158 - val_accuracy: 0.4181 - val_loss: 1.3112 - learning_rate: 0.0010
# Epoch 20/70
# 65/65 - 15s - 227ms/step - accuracy: 0.4831 - loss: 1.2186 - val_accuracy: 0.4046 - val_loss: 1.3309 - learning_rate: 0.0010
# Epoch 21/70
# 65/65 - 15s - 225ms/step - accuracy: 0.4889 - loss: 1.2121 - val_accuracy: 0.3988 - val_loss: 1.3360 - learning_rate: 0.0010
# Epoch 22/70
# 65/65 - 14s - 223ms/step - accuracy: 0.4937 - loss: 1.2009 - val_accuracy: 0.4066 - val_loss: 1.3412 - learning_rate: 0.0010
# Epoch 23/70
# 65/65 - 15s - 236ms/step - accuracy: 0.5005 - loss: 1.1812 - val_accuracy: 0.4162 - val_loss: 1.2887 - learning_rate: 0.0010
# Epoch 24/70
# 65/65 - 15s - 224ms/step - accuracy: 0.5014 - loss: 1.1804 - val_accuracy: 0.4412 - val_loss: 1.3146 - learning_rate: 0.0010
# Epoch 25/70
# 65/65 - 15s - 227ms/step - accuracy: 0.4983 - loss: 1.1740 - val_accuracy: 0.4258 - val_loss: 1.3282 - learning_rate: 0.0010
# Epoch 26/70
# 65/65 - 15s - 228ms/step - accuracy: 0.5058 - loss: 1.1674 - val_accuracy: 0.4143 - val_loss: 1.2972 - learning_rate: 0.0010
# Epoch 27/70
# 65/65 - 15s - 231ms/step - accuracy: 0.5113 - loss: 1.1579 - val_accuracy: 0.4046 - val_loss: 1.3424 - learning_rate: 0.0010
# Epoch 28/70
# 65/65 - 15s - 224ms/step - accuracy: 0.5265 - loss: 1.1522 - val_accuracy: 0.4355 - val_loss: 1.3266 - learning_rate: 0.0010
# Epoch 29/70
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 65/65 - 15s - 233ms/step - accuracy: 0.5140 - loss: 1.1530 - val_accuracy: 0.3911 - val_loss: 1.4417 - learning_rate: 0.0010
# Epoch 30/70
# 65/65 - 15s - 226ms/step - accuracy: 0.5434 - loss: 1.1084 - val_accuracy: 0.4200 - val_loss: 1.3340 - learning_rate: 5.0000e-04
# Epoch 31/70
# 65/65 - 15s - 231ms/step - accuracy: 0.5521 - loss: 1.0901 - val_accuracy: 0.4374 - val_loss: 1.2899 - learning_rate: 5.0000e-04
# Epoch 32/70
# 65/65 - 15s - 224ms/step - accuracy: 0.5560 - loss: 1.0968 - val_accuracy: 0.4451 - val_loss: 1.3214 - learning_rate: 5.0000e-04
# Epoch 33/70
# 65/65 - 15s - 229ms/step - accuracy: 0.5613 - loss: 1.0854 - val_accuracy: 0.4277 - val_loss: 1.3409 - learning_rate: 5.0000e-04
# Epoch 34/70
# 65/65 - 15s - 224ms/step - accuracy: 0.5620 - loss: 1.0784 - val_accuracy: 0.4412 - val_loss: 1.3391 - learning_rate: 5.0000e-04
# Epoch 35/70
# 65/65 - 15s - 227ms/step - accuracy: 0.5724 - loss: 1.0646 - val_accuracy: 0.4355 - val_loss: 1.3168 - learning_rate: 5.0000e-04
# Epoch 36/70
# 65/65 - 15s - 223ms/step - accuracy: 0.5712 - loss: 1.0617 - val_accuracy: 0.4374 - val_loss: 1.3265 - learning_rate: 5.0000e-04
# Epoch 37/70
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 65/65 - 15s - 232ms/step - accuracy: 0.5658 - loss: 1.0595 - val_accuracy: 0.4355 - val_loss: 1.3276 - learning_rate: 5.0000e-04
# Epoch 38/70
# 65/65 - 15s - 230ms/step - accuracy: 0.5837 - loss: 1.0435 - val_accuracy: 0.4470 - val_loss: 1.3074 - learning_rate: 2.5000e-04
# Epoch 39/70
# 65/65 - 15s - 225ms/step - accuracy: 0.5842 - loss: 1.0235 - val_accuracy: 0.4451 - val_loss: 1.3077 - learning_rate: 2.5000e-04
# Epoch 40/70
# 65/65 - 15s - 224ms/step - accuracy: 0.5784 - loss: 1.0418 - val_accuracy: 0.4489 - val_loss: 1.2905 - learning_rate: 2.5000e-04
# Epoch 41/70
# 65/65 - 15s - 234ms/step - accuracy: 0.5943 - loss: 1.0139 - val_accuracy: 0.4470 - val_loss: 1.2908 - learning_rate: 2.5000e-04
# Epoch 42/70
# 65/65 - 15s - 226ms/step - accuracy: 0.5996 - loss: 1.0114 - val_accuracy: 0.4200 - val_loss: 1.2928 - learning_rate: 2.5000e-04
# Epoch 43/70
# 65/65 - 15s - 234ms/step - accuracy: 0.5931 - loss: 1.0124 - val_accuracy: 0.4528 - val_loss: 1.3075 - learning_rate: 2.5000e-04
# Epoch 44/70
# 65/65 - 15s - 225ms/step - accuracy: 0.5914 - loss: 1.0019 - val_accuracy: 0.4586 - val_loss: 1.3087 - learning_rate: 2.5000e-04
# Epoch 45/70
# 65/65 - 15s - 231ms/step - accuracy: 0.6047 - loss: 0.9960 - val_accuracy: 0.4547 - val_loss: 1.3182 - learning_rate: 2.5000e-04
# Epoch 46/70
# 65/65 - 14s - 223ms/step - accuracy: 0.6008 - loss: 0.9963 - val_accuracy: 0.4393 - val_loss: 1.3230 - learning_rate: 2.5000e-04
# Epoch 47/70
# 65/65 - 15s - 227ms/step - accuracy: 0.6023 - loss: 1.0034 - val_accuracy: 0.4470 - val_loss: 1.3172 - learning_rate: 2.5000e-04
# Epoch 48/70
# 65/65 - 15s - 224ms/step - accuracy: 0.6006 - loss: 0.9957 - val_accuracy: 0.4470 - val_loss: 1.3123 - learning_rate: 2.5000e-04
# Epoch 49/70
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 65/65 - 15s - 233ms/step - accuracy: 0.6076 - loss: 0.9847 - val_accuracy: 0.4412 - val_loss: 1.3172 - learning_rate: 2.5000e-04
# Epoch 50/70
# 65/65 - 15s - 227ms/step - accuracy: 0.6170 - loss: 0.9770 - val_accuracy: 0.4412 - val_loss: 1.3156 - learning_rate: 1.2500e-04
# Epoch 51/70
# 65/65 - 15s - 227ms/step - accuracy: 0.6196 - loss: 0.9647 - val_accuracy: 0.4355 - val_loss: 1.3164 - learning_rate: 1.2500e-04
# Epoch 52/70
# 65/65 - 15s - 223ms/step - accuracy: 0.6245 - loss: 0.9689 - val_accuracy: 0.4374 - val_loss: 1.3248 - learning_rate: 1.2500e-04
# Epoch 53/70
# 65/65 - 15s - 225ms/step - accuracy: 0.6187 - loss: 0.9741 - val_accuracy: 0.4470 - val_loss: 1.3042 - learning_rate: 1.2500e-04
# Epoch 54/70
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 65/65 - 15s - 232ms/step - accuracy: 0.6151 - loss: 0.9710 - val_accuracy: 0.4489 - val_loss: 1.3211 - learning_rate: 1.2500e-04
# Epoch 55/70
# 65/65 - 15s - 234ms/step - accuracy: 0.6288 - loss: 0.9497 - val_accuracy: 0.4451 - val_loss: 1.3189 - learning_rate: 6.2500e-05
# Epoch 56/70
# 65/65 - 14s - 222ms/step - accuracy: 0.6199 - loss: 0.9609 - val_accuracy: 0.4509 - val_loss: 1.3128 - learning_rate: 6.2500e-05
# Epoch 1/70
# 65/65 - 48s - 732ms/step - accuracy: 0.2735 - loss: 1.5048 - val_accuracy: 0.2486 - val_loss: 1.4452 - learning_rate: 0.0010
# Epoch 2/70
# 65/65 - 41s - 635ms/step - accuracy: 0.2870 - loss: 1.4442 - val_accuracy: 0.2697 - val_loss: 1.4422 - learning_rate: 0.0010
# Epoch 3/70
# 65/65 - 43s - 657ms/step - accuracy: 0.3041 - loss: 1.4272 - val_accuracy: 0.2929 - val_loss: 1.4305 - learning_rate: 0.0010
# Epoch 4/70
# 65/65 - 42s - 643ms/step - accuracy: 0.3174 - loss: 1.4108 - val_accuracy: 0.3179 - val_loss: 1.4117 - learning_rate: 0.0010
# Epoch 5/70
# 65/65 - 42s - 647ms/step - accuracy: 0.3326 - loss: 1.3984 - val_accuracy: 0.3796 - val_loss: 1.3952 - learning_rate: 0.0010
# Epoch 6/70
# 65/65 - 41s - 631ms/step - accuracy: 0.3608 - loss: 1.3736 - val_accuracy: 0.4046 - val_loss: 1.3674 - learning_rate: 0.0010
# Epoch 7/70
# 65/65 - 42s - 640ms/step - accuracy: 0.3808 - loss: 1.3616 - val_accuracy: 0.3950 - val_loss: 1.3624 - learning_rate: 0.0010
# Epoch 8/70
# 65/65 - 42s - 644ms/step - accuracy: 0.3888 - loss: 1.3500 - val_accuracy: 0.4027 - val_loss: 1.3421 - learning_rate: 0.0010
# Epoch 9/70
# 65/65 - 42s - 639ms/step - accuracy: 0.3934 - loss: 1.3337 - val_accuracy: 0.4239 - val_loss: 1.3224 - learning_rate: 0.0010
# Epoch 10/70
# 65/65 - 42s - 652ms/step - accuracy: 0.4083 - loss: 1.3215 - val_accuracy: 0.4123 - val_loss: 1.3136 - learning_rate: 0.0010
# Epoch 11/70
# 65/65 - 41s - 633ms/step - accuracy: 0.4158 - loss: 1.3081 - val_accuracy: 0.4200 - val_loss: 1.3113 - learning_rate: 0.0010
# Epoch 12/70
# 65/65 - 42s - 653ms/step - accuracy: 0.4228 - loss: 1.3010 - val_accuracy: 0.4239 - val_loss: 1.3001 - learning_rate: 0.0010
# Epoch 13/70
# 65/65 - 41s - 632ms/step - accuracy: 0.4197 - loss: 1.3001 - val_accuracy: 0.4335 - val_loss: 1.2878 - learning_rate: 0.0010
# Epoch 14/70
# 65/65 - 52s - 801ms/step - accuracy: 0.4257 - loss: 1.2970 - val_accuracy: 0.4566 - val_loss: 1.2667 - learning_rate: 0.0010
# Epoch 15/70
# 65/65 - 44s - 684ms/step - accuracy: 0.4211 - loss: 1.2816 - val_accuracy: 0.4451 - val_loss: 1.2756 - learning_rate: 0.0010
# Epoch 16/70
# 65/65 - 40s - 623ms/step - accuracy: 0.4370 - loss: 1.2804 - val_accuracy: 0.4509 - val_loss: 1.2565 - learning_rate: 0.0010
# Epoch 17/70
# 65/65 - 41s - 627ms/step - accuracy: 0.4460 - loss: 1.2678 - val_accuracy: 0.4489 - val_loss: 1.2677 - learning_rate: 0.0010
# Epoch 18/70
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 65/65 - 41s - 633ms/step - accuracy: 0.4404 - loss: 1.2608 - val_accuracy: 0.4547 - val_loss: 1.2640 - learning_rate: 0.0010
# Epoch 19/70
# 65/65 - 41s - 627ms/step - accuracy: 0.4571 - loss: 1.2387 - val_accuracy: 0.4470 - val_loss: 1.2403 - learning_rate: 5.0000e-04
# Epoch 20/70
# 65/65 - 41s - 628ms/step - accuracy: 0.4735 - loss: 1.2199 - val_accuracy: 0.4432 - val_loss: 1.2457 - learning_rate: 5.0000e-04
# Epoch 21/70
# 65/65 - 40s - 622ms/step - accuracy: 0.4691 - loss: 1.2206 - val_accuracy: 0.4644 - val_loss: 1.2340 - learning_rate: 5.0000e-04
# Epoch 22/70
# 65/65 - 41s - 624ms/step - accuracy: 0.4703 - loss: 1.2160 - val_accuracy: 0.4432 - val_loss: 1.2402 - learning_rate: 5.0000e-04
# Epoch 23/70
# 65/65 - 41s - 628ms/step - accuracy: 0.4699 - loss: 1.2111 - val_accuracy: 0.4566 - val_loss: 1.2433 - learning_rate: 5.0000e-04
# Epoch 24/70
# 65/65 - 43s - 656ms/step - accuracy: 0.4942 - loss: 1.1963 - val_accuracy: 0.4355 - val_loss: 1.2422 - learning_rate: 5.0000e-04
# Epoch 25/70
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 65/65 - 50s - 776ms/step - accuracy: 0.4826 - loss: 1.2001 - val_accuracy: 0.4316 - val_loss: 1.2454 - learning_rate: 5.0000e-04
# Epoch 26/70
# 65/65 - 47s - 724ms/step - accuracy: 0.4884 - loss: 1.1846 - val_accuracy: 0.4586 - val_loss: 1.2232 - learning_rate: 2.5000e-04
# Epoch 27/70
# 65/65 - 44s - 673ms/step - accuracy: 0.5031 - loss: 1.1757 - val_accuracy: 0.4798 - val_loss: 1.2159 - learning_rate: 2.5000e-04
# Epoch 28/70
# 65/65 - 43s - 665ms/step - accuracy: 0.5014 - loss: 1.1674 - val_accuracy: 0.4624 - val_loss: 1.2195 - learning_rate: 2.5000e-04
# Epoch 29/70
# 65/65 - 44s - 674ms/step - accuracy: 0.5065 - loss: 1.1627 - val_accuracy: 0.4624 - val_loss: 1.2178 - learning_rate: 2.5000e-04
# Epoch 30/70
# 65/65 - 47s - 722ms/step - accuracy: 0.5010 - loss: 1.1680 - val_accuracy: 0.4759 - val_loss: 1.2116 - learning_rate: 2.5000e-04
# Epoch 31/70
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 65/65 - 45s - 688ms/step - accuracy: 0.5070 - loss: 1.1587 - val_accuracy: 0.4682 - val_loss: 1.2051 - learning_rate: 2.5000e-04
# Epoch 32/70
# 65/65 - 44s - 680ms/step - accuracy: 0.5116 - loss: 1.1585 - val_accuracy: 0.4528 - val_loss: 1.2045 - learning_rate: 1.2500e-04
# Epoch 33/70
# 65/65 - 43s - 667ms/step - accuracy: 0.5150 - loss: 1.1459 - val_accuracy: 0.4682 - val_loss: 1.2071 - learning_rate: 1.2500e-04
# Epoch 34/70
# 65/65 - 42s - 641ms/step - accuracy: 0.5154 - loss: 1.1447 - val_accuracy: 0.4528 - val_loss: 1.2048 - learning_rate: 1.2500e-04
# Epoch 35/70
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 65/65 - 42s - 645ms/step - accuracy: 0.5072 - loss: 1.1500 - val_accuracy: 0.4528 - val_loss: 1.2123 - learning_rate: 1.2500e-04
# Epoch 36/70
# 65/65 - 41s - 634ms/step - accuracy: 0.5171 - loss: 1.1449 - val_accuracy: 0.4586 - val_loss: 1.2102 - learning_rate: 6.2500e-05
# Epoch 37/70
# 65/65 - 47s - 721ms/step - accuracy: 0.5229 - loss: 1.1404 - val_accuracy: 0.4586 - val_loss: 1.2096 - learning_rate: 6.2500e-05
# Epoch 1/70
# 65/65 - 20s - 304ms/step - accuracy: 0.2769 - loss: 2.1187 - val_accuracy: 0.2447 - val_loss: 1.6205 - learning_rate: 0.0010
# Epoch 2/70
# 65/65 - 16s - 252ms/step - accuracy: 0.2738 - loss: 1.7719 - val_accuracy: 0.2601 - val_loss: 1.6481 - learning_rate: 0.0010
# Epoch 3/70
# 65/65 - 15s - 228ms/step - accuracy: 0.2834 - loss: 1.6340 - val_accuracy: 0.2775 - val_loss: 1.4647 - learning_rate: 0.0010
# Epoch 4/70
# 65/65 - 15s - 227ms/step - accuracy: 0.2952 - loss: 1.5718 - val_accuracy: 0.2909 - val_loss: 1.4277 - learning_rate: 0.0010
# Epoch 5/70
# 65/65 - 16s - 250ms/step - accuracy: 0.3073 - loss: 1.5278 - val_accuracy: 0.2967 - val_loss: 1.4384 - learning_rate: 0.0010
# Epoch 6/70
# 65/65 - 14s - 223ms/step - accuracy: 0.3300 - loss: 1.4851 - val_accuracy: 0.2659 - val_loss: 1.4592 - learning_rate: 0.0010
# Epoch 7/70
# 65/65 - 15s - 224ms/step - accuracy: 0.3507 - loss: 1.4442 - val_accuracy: 0.2351 - val_loss: 1.6238 - learning_rate: 0.0010
# Epoch 8/70
# 65/65 - 16s - 251ms/step - accuracy: 0.3514 - loss: 1.4228 - val_accuracy: 0.3218 - val_loss: 1.4476 - learning_rate: 0.0010
# Epoch 9/70
# 65/65 - 16s - 245ms/step - accuracy: 0.3837 - loss: 1.3962 - val_accuracy: 0.3507 - val_loss: 1.4112 - learning_rate: 0.0010
# Epoch 10/70
# 65/65 - 14s - 218ms/step - accuracy: 0.3907 - loss: 1.3611 - val_accuracy: 0.3699 - val_loss: 1.4750 - learning_rate: 0.0010
# Epoch 11/70
# 65/65 - 14s - 221ms/step - accuracy: 0.3944 - loss: 1.3454 - val_accuracy: 0.3892 - val_loss: 1.4335 - learning_rate: 0.0010
# Epoch 12/70
# 65/65 - 15s - 236ms/step - accuracy: 0.4165 - loss: 1.3266 - val_accuracy: 0.3931 - val_loss: 1.3836 - learning_rate: 0.0010
# Epoch 13/70
# 65/65 - 17s - 254ms/step - accuracy: 0.4288 - loss: 1.3027 - val_accuracy: 0.3603 - val_loss: 1.4769 - learning_rate: 0.0010
# Epoch 14/70
# 65/65 - 14s - 221ms/step - accuracy: 0.4440 - loss: 1.2828 - val_accuracy: 0.3661 - val_loss: 1.4185 - learning_rate: 0.0010
# Epoch 15/70
# 65/65 - 14s - 221ms/step - accuracy: 0.4428 - loss: 1.2738 - val_accuracy: 0.3815 - val_loss: 1.4288 - learning_rate: 0.0010
# Epoch 16/70
# 65/65 - 15s - 231ms/step - accuracy: 0.4609 - loss: 1.2447 - val_accuracy: 0.3719 - val_loss: 1.4321 - learning_rate: 0.0010
# Epoch 17/70
# 65/65 - 14s - 223ms/step - accuracy: 0.4670 - loss: 1.2341 - val_accuracy: 0.3988 - val_loss: 1.3796 - learning_rate: 0.0010
# Epoch 18/70
# 65/65 - 14s - 219ms/step - accuracy: 0.4742 - loss: 1.2285 - val_accuracy: 0.4085 - val_loss: 1.4122 - learning_rate: 0.0010
# Epoch 19/70
# 65/65 - 14s - 222ms/step - accuracy: 0.4747 - loss: 1.2175 - val_accuracy: 0.4335 - val_loss: 1.3480 - learning_rate: 0.0010
# Epoch 20/70
# 65/65 - 16s - 244ms/step - accuracy: 0.4872 - loss: 1.1989 - val_accuracy: 0.4046 - val_loss: 1.3961 - learning_rate: 0.0010
# Epoch 21/70
# 65/65 - 16s - 247ms/step - accuracy: 0.5022 - loss: 1.1789 - val_accuracy: 0.4200 - val_loss: 1.3864 - learning_rate: 0.0010
# Epoch 22/70
# 65/65 - 16s - 245ms/step - accuracy: 0.5176 - loss: 1.1569 - val_accuracy: 0.4220 - val_loss: 1.3695 - learning_rate: 0.0010
# Epoch 23/70
# 65/65 - 15s - 225ms/step - accuracy: 0.5200 - loss: 1.1548 - val_accuracy: 0.4143 - val_loss: 1.3757 - learning_rate: 0.0010
# Epoch 24/70
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 65/65 - 14s - 221ms/step - accuracy: 0.5258 - loss: 1.1458 - val_accuracy: 0.4220 - val_loss: 1.4486 - learning_rate: 0.0010
# Epoch 25/70
# 65/65 - 14s - 221ms/step - accuracy: 0.5603 - loss: 1.1084 - val_accuracy: 0.4355 - val_loss: 1.3304 - learning_rate: 5.0000e-04
# Epoch 26/70
# 65/65 - 16s - 245ms/step - accuracy: 0.5827 - loss: 1.0776 - val_accuracy: 0.4432 - val_loss: 1.3268 - learning_rate: 5.0000e-04
# Epoch 27/70
# 65/65 - 15s - 225ms/step - accuracy: 0.5603 - loss: 1.0800 - val_accuracy: 0.4528 - val_loss: 1.3196 - learning_rate: 5.0000e-04
# Epoch 28/70
# 65/65 - 14s - 220ms/step - accuracy: 0.5589 - loss: 1.0629 - val_accuracy: 0.4297 - val_loss: 1.3524 - learning_rate: 5.0000e-04
# Epoch 29/70
# 65/65 - 15s - 226ms/step - accuracy: 0.5902 - loss: 1.0390 - val_accuracy: 0.4066 - val_loss: 1.3476 - learning_rate: 5.0000e-04
# Epoch 30/70
# 65/65 - 14s - 223ms/step - accuracy: 0.5806 - loss: 1.0451 - val_accuracy: 0.4335 - val_loss: 1.3304 - learning_rate: 5.0000e-04
# Epoch 31/70
# 65/65 - 14s - 223ms/step - accuracy: 0.5767 - loss: 1.0490 - val_accuracy: 0.4412 - val_loss: 1.3419 - learning_rate: 5.0000e-04
# Epoch 32/70
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 65/65 - 15s - 236ms/step - accuracy: 0.5904 - loss: 1.0292 - val_accuracy: 0.4277 - val_loss: 1.3397 - learning_rate: 5.0000e-04
# Epoch 33/70
# 65/65 - 16s - 244ms/step - accuracy: 0.6037 - loss: 1.0109 - val_accuracy: 0.4432 - val_loss: 1.3288 - learning_rate: 2.5000e-04
# Epoch 34/70
# 65/65 - 16s - 252ms/step - accuracy: 0.6076 - loss: 0.9916 - val_accuracy: 0.4374 - val_loss: 1.3526 - learning_rate: 2.5000e-04
# Epoch 35/70
# 65/65 - 16s - 244ms/step - accuracy: 0.6015 - loss: 0.9962 - val_accuracy: 0.4412 - val_loss: 1.3301 - learning_rate: 2.5000e-04
# Epoch 36/70
# 65/65 - 16s - 244ms/step - accuracy: 0.6172 - loss: 0.9913 - val_accuracy: 0.4509 - val_loss: 1.3328 - learning_rate: 2.5000e-04
# Epoch 37/70
# 65/65 - 14s - 220ms/step - accuracy: 0.6230 - loss: 0.9714 - val_accuracy: 0.4605 - val_loss: 1.3533 - learning_rate: 2.5000e-04
# Epoch 38/70
# 65/65 - 14s - 218ms/step - accuracy: 0.6179 - loss: 0.9799 - val_accuracy: 0.4566 - val_loss: 1.3224 - learning_rate: 2.5000e-04
# Epoch 39/70
# 65/65 - 14s - 219ms/step - accuracy: 0.6363 - loss: 0.9660 - val_accuracy: 0.4509 - val_loss: 1.3395 - learning_rate: 2.5000e-04
# Epoch 40/70
# 65/65 - 14s - 218ms/step - accuracy: 0.6208 - loss: 0.9630 - val_accuracy: 0.4355 - val_loss: 1.3515 - learning_rate: 2.5000e-04
# Epoch 41/70
# 65/65 - 16s - 240ms/step - accuracy: 0.6175 - loss: 0.9795 - val_accuracy: 0.4412 - val_loss: 1.3363 - learning_rate: 2.5000e-04
# Epoch 42/70
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 65/65 - 21s - 324ms/step - accuracy: 0.6343 - loss: 0.9464 - val_accuracy: 0.4509 - val_loss: 1.3499 - learning_rate: 2.5000e-04
# Epoch 43/70
# 65/65 - 18s - 275ms/step - accuracy: 0.6351 - loss: 0.9520 - val_accuracy: 0.4412 - val_loss: 1.3678 - learning_rate: 1.2500e-04
# Epoch 44/70
# 65/65 - 17s - 264ms/step - accuracy: 0.6421 - loss: 0.9351 - val_accuracy: 0.4566 - val_loss: 1.3718 - learning_rate: 1.2500e-04
# Epoch 45/70
# 65/65 - 18s - 276ms/step - accuracy: 0.6450 - loss: 0.9346 - val_accuracy: 0.4316 - val_loss: 1.3532 - learning_rate: 1.2500e-04
# Epoch 46/70
# 65/65 - 17s - 260ms/step - accuracy: 0.6522 - loss: 0.9254 - val_accuracy: 0.4566 - val_loss: 1.3542 - learning_rate: 1.2500e-04
# Epoch 47/70
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 65/65 - 17s - 262ms/step - accuracy: 0.6534 - loss: 0.9182 - val_accuracy: 0.4489 - val_loss: 1.3467 - learning_rate: 1.2500e-04
# Epoch 48/70
# 65/65 - 16s - 245ms/step - accuracy: 0.6481 - loss: 0.9238 - val_accuracy: 0.4566 - val_loss: 1.3614 - learning_rate: 6.2500e-05
# Epoch 49/70
# 65/65 - 18s - 272ms/step - accuracy: 0.6493 - loss: 0.9238 - val_accuracy: 0.4605 - val_loss: 1.3586 - learning_rate: 6.2500e-05
# Epoch 1/70
# 65/65 - 62s - 955ms/step - accuracy: 0.2564 - loss: 1.5314 - val_accuracy: 0.2524 - val_loss: 1.4458 - learning_rate: 0.0010
# Epoch 2/70
# 65/65 - 42s - 650ms/step - accuracy: 0.2921 - loss: 1.4438 - val_accuracy: 0.2505 - val_loss: 1.4981 - learning_rate: 0.0010
# Epoch 3/70
# 65/65 - 40s - 621ms/step - accuracy: 0.3020 - loss: 1.4282 - val_accuracy: 0.3064 - val_loss: 1.4564 - learning_rate: 0.0010
# Epoch 4/70
# 65/65 - 41s - 625ms/step - accuracy: 0.3350 - loss: 1.4029 - val_accuracy: 0.2620 - val_loss: 1.4306 - learning_rate: 0.0010
# Epoch 5/70
# 65/65 - 40s - 623ms/step - accuracy: 0.3584 - loss: 1.3810 - val_accuracy: 0.4220 - val_loss: 1.3513 - learning_rate: 0.0010
# Epoch 6/70
# 65/65 - 40s - 623ms/step - accuracy: 0.3821 - loss: 1.3570 - val_accuracy: 0.4143 - val_loss: 1.3217 - learning_rate: 0.0010
# Epoch 7/70
# 65/65 - 45s - 695ms/step - accuracy: 0.3958 - loss: 1.3444 - val_accuracy: 0.4220 - val_loss: 1.3266 - learning_rate: 0.0010
# Epoch 8/70
# 65/65 - 47s - 728ms/step - accuracy: 0.4040 - loss: 1.3249 - val_accuracy: 0.4470 - val_loss: 1.3203 - learning_rate: 0.0010
# Epoch 9/70
# 65/65 - 46s - 714ms/step - accuracy: 0.4021 - loss: 1.3201 - val_accuracy: 0.4412 - val_loss: 1.3288 - learning_rate: 0.0010
# Epoch 10/70
# 65/65 - 47s - 716ms/step - accuracy: 0.4129 - loss: 1.3091 - val_accuracy: 0.4335 - val_loss: 1.2789 - learning_rate: 0.0010
# Epoch 11/70
# 65/65 - 46s - 715ms/step - accuracy: 0.4329 - loss: 1.2904 - val_accuracy: 0.4509 - val_loss: 1.2679 - learning_rate: 0.0010
# Epoch 12/70
# 65/65 - 47s - 719ms/step - accuracy: 0.4305 - loss: 1.2858 - val_accuracy: 0.4470 - val_loss: 1.2716 - learning_rate: 0.0010
# Epoch 13/70
# 65/65 - 47s - 716ms/step - accuracy: 0.4378 - loss: 1.2743 - val_accuracy: 0.4528 - val_loss: 1.2536 - learning_rate: 0.0010
# Epoch 14/70
# 65/65 - 46s - 714ms/step - accuracy: 0.4426 - loss: 1.2648 - val_accuracy: 0.4451 - val_loss: 1.2587 - learning_rate: 0.0010
# Epoch 15/70
# 65/65 - 46s - 712ms/step - accuracy: 0.4424 - loss: 1.2623 - val_accuracy: 0.4509 - val_loss: 1.2449 - learning_rate: 0.0010
# Epoch 16/70

# %% [markdown]
# ## Learning Curves
# Once training finishes, run the cell below to visualise accuracy and loss trends for each dataset/model.

# %%
if not model_registry:
    print('No training histories found. Run training first.')
else:
    for name, artifacts in model_registry.items():
        plt.figure(figsize=(12, 5))
        plt.suptitle(f"{name} learning curves")

        plt.subplot(1, 2, 1)
        plt.plot(artifacts['cnn_history']['accuracy'], label='CNN Train')
        plt.plot(artifacts['cnn_history']['val_accuracy'], label='CNN Val')
        plt.plot(artifacts['gcn_history']['accuracy'], label='GCN Train')
        plt.plot(artifacts['gcn_history']['val_accuracy'], label='GCN Val')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(artifacts['cnn_history']['loss'], label='CNN Train')
        plt.plot(artifacts['cnn_history']['val_loss'], label='CNN Val')
        plt.plot(artifacts['gcn_history']['loss'], label='GCN Train')
        plt.plot(artifacts['gcn_history']['val_loss'], label='GCN Val')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()

        plt.tight_layout()
        plt.show()

# %% [markdown]
# ## Cross-Dataset Comparison
# When the  is available, this cell builds a visual summary.

# %%
if 'results_df' not in globals() or results_df.empty:
    print('No results dataframe available. Run training first.')
else:
    metric_names = ['accuracy', 'precision', 'recall', 'f1']
    fig, axes = plt.subplots(1, len(metric_names), figsize=(5 * len(metric_names), 5), sharey=False)
    if len(metric_names) == 1:
        axes = [axes]
    for ax, metric in zip(axes, metric_names):
        sns.barplot(data=results_df, x='dataset', y=metric, hue='model', ax=ax)
        ax.set_title(metric.title())
        ax.set_ylim(0, 1)
        ax.set_xlabel('Dataset')
        ax.set_ylabel(metric.title())
        if ax is not axes[0]:
            ax.legend_.remove()
    handles, labels = axes[0].get_legend_handles_labels()
    axes[0].legend(handles, labels, title='Model')
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(6, 5))
    sns.barplot(data=results_df, x='dataset', y='loss', hue='model')
    plt.title('Validation loss by dataset and model')
    plt.xlabel('Dataset')
    plt.ylabel('Loss')
    plt.tight_layout()
    plt.show()

# %%
if not reports_registry:
    print('No classification reports available. Run training first.')
else:
    for dataset_name, model_reports in reports_registry.items():
        print(f"=== {dataset_name} ===")
        for model_name, report_dict in model_reports.items():
            print(f"=== {model_name} ===")
            normalized = {}
            for label, stats in report_dict.items():
                if isinstance(stats, dict):
                    normalized[label] = stats
                else:
                    normalized[label] = {'score': stats}
            report_df = pd.DataFrame.from_dict(normalized, orient='index')
            columns_to_show = [col for col in ['precision', 'recall', 'f1-score', 'support', 'score'] if col in report_df.columns]
            display(report_df[columns_to_show])
# Out:
# === BCI_2a ===
# === CNN ===
#               precision    recall  f1-score  support     score
# foot           0.496503  0.546154  0.520147    130.0       NaN
# left_hand      0.601626  0.573643  0.587302    129.0       NaN
# right_hand     0.602837  0.653846  0.627306    130.0       NaN
# tongue         0.607143  0.523077  0.561983    130.0       NaN
# macro avg      0.577027  0.574180  0.574184    519.0       NaN
# weighted avg   0.576980  0.574181  0.574159    519.0       NaN
# accuracy            NaN       NaN       NaN      NaN  0.574181
# === GCN ===
#               precision    recall  f1-score  support     score
# foot           0.500000  0.523077  0.511278    130.0       NaN
# left_hand      0.541667  0.604651  0.571429    129.0       NaN
# right_hand     0.641667  0.592308  0.616000    130.0       NaN
# tongue         0.588235  0.538462  0.562249    130.0       NaN
# macro avg      0.567892  0.564624  0.565239    519.0       NaN
# weighted avg   0.567943  0.564547  0.565227    519.0       NaN
# accuracy            NaN       NaN       NaN      NaN  0.564547
# === BCI_2b ===
# === CNN ===
#               precision    recall  f1-score  support     score
# left_hand      0.744565  0.744565  0.744565    368.0       NaN
# right_hand     0.744565  0.744565  0.744565    368.0       NaN
# macro avg      0.744565  0.744565  0.744565    736.0       NaN
# weighted avg   0.744565  0.744565  0.744565    736.0       NaN
# accuracy            NaN       NaN       NaN      NaN  0.744565
# === GCN ===
#               precision    recall  f1-score  support     score
# left_hand      0.736842  0.760870  0.748663    368.0       NaN
# right_hand     0.752809  0.728261  0.740331    368.0       NaN
# macro avg      0.744826  0.744565  0.744497    736.0       NaN
# weighted avg   0.744826  0.744565  0.744497    736.0       NaN
# accuracy            NaN       NaN       NaN      NaN  0.744565
# === PhysioNet ===
# === CNN ===
#               precision    recall  f1-score  support     score
# left_fist      0.739130  0.944444  0.829268     18.0       NaN
# right_fist     0.923077  0.666667  0.774194     18.0       NaN
# macro avg      0.831104  0.805556  0.801731     36.0       NaN
# weighted avg   0.831104  0.805556  0.801731     36.0       NaN
# accuracy            NaN       NaN       NaN      NaN  0.805556
# === GCN ===
#               precision    recall  f1-score  support     score
# left_fist      0.833333  0.555556  0.666667     18.0       NaN
# right_fist     0.666667  0.888889  0.761905     18.0       NaN
# macro avg      0.750000  0.722222  0.714286     36.0       NaN
# weighted avg   0.750000  0.722222  0.714286     36.0       NaN
# accuracy            NaN       NaN       NaN      NaN  0.722222

# %% [markdown]
# ## Next Steps
# - Expand the subject/run lists once the pipeline runs smoothly on this subset.
# - Experiment with more expressive graph constructions (distance-based, mutual information).
# - Evaluate ES/AS channel selection on top of the trained models to identify minimal electrode sets.
# - Consider cross-subject generalisation by holding out entire subjects for validation.
